# %%
# !pip install timm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /usr4/cs523/tengzi/.local/lib/python3.8/site-packages (0.4.9)
# Requirement already satisfied: torch>=1.4 in /share/pkg.7/pytorch/1.8.1/install/lib/python3.8/site-packages (from timm) (1.8.1+cu111)
# Requirement already satisfied: torchvision in /share/pkg.7/pytorch/1.8.1/install/lib/python3.8/site-packages (from timm) (0.9.1+cu111)
# Requirement already satisfied: typing-extensions in /share/pkg.7/python3/3.8.6/install/lib/python3.8/site-packages (from torch>=1.4->timm) (3.7.4.3)
# Requirement already satisfied: numpy in /share/pkg.7/python3/3.8.6/install/lib/python3.8/site-packages/numpy-1.19.4-py3.8-linux-x86_64.egg (from torch>=1.4->timm) (1.19.4)
# Requirement already satisfied: pillow>=4.1.1 in /share/pkg.7/python3/3.8.6/install/lib/python3.8/site-packages (from torchvision->timm) (8.0.1)
# WARNING: You are using pip version 20.2.4; however, version 21.1.2 is available.
# You should consider upgrading via the '/share/pkg.7/python3/3.8.6/install/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import sys
import warnings

import torch
import torch.nn as nn
from torch.cuda.amp import GradScaler
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
import numpy as np
import pandas as pd
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from PIL import Image
from torch.utils.data import Dataset
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None, augment=False):
        self.images = images
        self.labels = labels
        self.transform = transform

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img = np.array(self.images[idx])

        img = Image.fromarray(img)

        if self.transform:
            img = self.transform(img)

        label = torch.tensor(self.labels[idx]).type(torch.long)
        sample = (img, label)

        return sample
    
def load_data(path='datasets/fer2013/fer2013.csv'):
    fer2013 = pd.read_csv(path)
    emotion_mapping = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}

    return fer2013, emotion_mapping


def prepare_data(data):
    """ Prepare data for modeling
        input: data frame with labels und pixel data
        output: image and label array """

    image_array = np.zeros(shape=(len(data), 48, 48))
    image_label = np.array(list(map(int, data['emotion'])))

    for i, row in enumerate(data.index):
        image = np.fromstring(data.loc[row, 'pixels'], dtype=int, sep=' ')
        image = np.reshape(image, (48, 48))
        image_array[i] = image

    return image_array, image_label

def get_dataloaders(path='datasets/fer2013/fer2013.csv', bs=64, augment=True):
    """ Prepare train, val, & test dataloaders
        Augment training data using:
            - cropping
            - shifting (vertical/horizental)
            - horizental flipping
            - rotation

        input: path to fer2013 csv file
        output: (Dataloader, Dataloader, Dataloader) """

    fer2013, emotion_mapping = load_data(path)

    xtrain, ytrain = prepare_data(fer2013[fer2013['Usage'] == 'Training'])
    xval, yval = prepare_data(fer2013[fer2013['Usage'] == 'PrivateTest'])
    xtest, ytest = prepare_data(fer2013[fer2013['Usage'] == 'PublicTest'])

    mu, st = 0, 255

    test_transform = transforms.Compose([
        # transforms.Scale(52),
        transforms.TenCrop(40),
        transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
        transforms.Lambda(lambda tensors: torch.stack([transforms.Normalize(mean=(mu,), std=(st,))(t) for t in tensors])),
    ])

    if augment:
        train_transform = transforms.Compose([
            transforms.RandomResizedCrop(48, scale=(0.8, 1.2)),
            transforms.RandomApply([transforms.RandomAffine(0, translate=(0.2, 0.2))], p=0.5),
            transforms.RandomHorizontalFlip(),
            transforms.RandomApply([transforms.RandomRotation(10)], p=0.5),

            transforms.TenCrop(40),
            transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
            transforms.Lambda(lambda tensors: torch.stack([transforms.Normalize(mean=(mu,), std=(st,))(t) for t in tensors])),
            transforms.Lambda(lambda tensors: torch.stack([transforms.RandomErasing(p=0.5)(t) for t in tensors])),
        ])
    else:
        train_transform = test_transform

    # X = np.vstack((xtrain, xval))
    # Y = np.hstack((ytrain, yval))

    train = CustomDataset(xtrain, ytrain, train_transform)
    val = CustomDataset(xval, yval, test_transform)
    test = CustomDataset(xtest, ytest, test_transform)

    trainloader = DataLoader(train, batch_size=bs, shuffle=True, num_workers=2)
    valloader = DataLoader(val, batch_size=64, shuffle=True, num_workers=2)
    testloader = DataLoader(test, batch_size=64, shuffle=True, num_workers=2)

    return trainloader, valloader, testloader

# %%
import os
def save(net, logger, hps, epoch):
    # Create the path the checkpint will be saved at using the epoch number
    path = os.path.join(hps['model_save_dir'], 'epoch_' + str(epoch))

    # create a dictionary containing the logger info and model info that will be saved
    checkpoint = {
        'logs': logger.get_logs(),
        'params': net.state_dict()
    }

    # save checkpoint
    torch.save(checkpoint, path)


def restore(net, logger, hps):
    """ Load back the model and logger from a given checkpoint
        epoch detailed in hps['restore_epoch'], if available"""
    path = os.path.join(hps['model_save_dir'], 'epoch_' + str(hps['restore_epoch']))

    if os.path.exists(path):
        try:
            checkpoint = torch.load(path)

            logger.restore_logs(checkpoint['logs'])
            net.load_state_dict(checkpoint['params'])
            print("Network Restored!")

        except Exception as e:
            print("Restore Failed! Training from scratch.")
            print(e)
            hps['start_epoch'] = 0

    else:
        print("Restore point unavailable. Training from scratch.")
        hps['start_epoch'] = 0


def load_features(model, params):
    """ Load params into all layers of 'model'
        that are compatible, then freeze them"""
    model_dict = model.state_dict()

    imp_params = {k: v for k, v in params.items() if k in model_dict}

    # Load layers
    model_dict.update(imp_params)
    model.load_state_dict(imp_params)

    # Freeze layers
    for name, param in model.named_parameters():
        param.requires_grad = False

# %%
hps = {
    'network': 'vgg',  # which network do you want to train
    'name': 'myvgg',  # whatever you want to name your run
    'n_epochs': 300,
    'model_save_dir': None,  # where will checkpoints be stored (path created automatically using hps[name])
    'restore_epoch': None,  # continue training from a specific saved point
    'start_epoch': 0,
    'lr': 0.01,  # starting learning rate
    'save_freq': 20,  # how often to create checkpoints
    'drop': 0.1,
    'bs': 64,
}
hps['model_save_dir'] = os.path.join(os.getcwd(), 'vgg_fine_tuning/checkpoint', hps['name'])

if not os.path.exists(hps['model_save_dir']):
    os.makedirs(hps['model_save_dir'])

# %%
from torch.cuda.amp import autocast

warnings.filterwarnings("ignore")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def train(net, dataloader, criterion, optimizer, scaler, Ncrop=True):
    net = net.train()
    loss_tr, correct_count, n_samples = 0.0, 0.0, 0.0
    iters = len(dataloader)  # number of batches, not images

    for i, data in enumerate(dataloader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        with autocast():
            if Ncrop:
                # fuse crops and batchsize
                bs, ncrops, c, h, w = inputs.shape
                inputs = inputs.view(-1, c, h, w)

            # repeat labels ncrops times
            labels = torch.repeat_interleave(labels, repeats=ncrops, dim=0)

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            scaler.scale(loss).backward()

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            # scheduler.step(epoch + i / iters)

            # calculate performance metrics
            loss_tr += loss.item()

            _, preds = torch.max(outputs.data, 1)
            correct_count += (preds == labels).sum().item()
            n_samples += labels.size(0)

    acc = 100 * correct_count / n_samples
    loss = loss_tr / n_samples

    return acc, loss


def evaluate(net, dataloader, criterion, Ncrop=True):
    net = net.eval()
    loss_tr, correct_count, n_samples = 0.0, 0.0, 0.0
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        if Ncrop:
            # fuse crops and batchsize
            bs, ncrops, c, h, w = inputs.shape
            inputs = inputs.view(-1, c, h, w)
            # forward
            outputs = net(inputs)
            # combine results across the crops
            outputs = outputs.view(bs, ncrops, -1)
            outputs = torch.sum(outputs, dim=1) / ncrops
        else:
            outputs = net(inputs)

        loss = criterion(outputs, labels)

        # calculate performance metrics
        loss_tr += loss.item()

        _, preds = torch.max(outputs.data, 1)
        correct_count += (preds == labels).sum().item()
        n_samples += labels.size(0)

    acc = 100 * correct_count / n_samples
    loss = loss_tr / n_samples

    return acc, loss

# %%
from matplotlib import pyplot as plt

class Logger:
    def __init__(self):
        self.loss_train = []
        self.loss_val = []

        self.acc_train = []
        self.acc_val = []

    def get_logs(self):
        return self.loss_train, self.loss_val, self.acc_train, self.acc_val

    def restore_logs(self, logs):
        self.loss_train, self.loss_val, self.acc_train, self.acc_val = logs

    def save_plt(self, hps):
        loss_path = os.path.join(hps['model_save_dir'], 'loss.jpg')
        acc_path = os.path.join(hps['model_save_dir'], 'acc.jpg')

        plt.figure()
        plt.plot(self.acc_train, 'g', label='Training Acc')
        plt.plot(self.acc_val, 'b', label='Validation Acc')
        plt.title('Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Acc')
        plt.legend()
        plt.grid()
        plt.savefig(acc_path)

        plt.figure()
        plt.plot(self.loss_train, 'g', label='Training Loss')
        plt.plot(self.loss_val, 'b', label='Validation Loss')
        plt.title('Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid()
        plt.savefig(loss_path)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torchvision

class VggFeatures(nn.Module):
    def __init__(self, drop=0.2):
        super().__init__()

        self.conv1a = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1)
        self.conv1b = nn.Conv2d(64, out_channels=64, kernel_size=3, padding=1)

        self.conv2a = nn.Conv2d(64, 128, 3, padding=1)
        self.conv2b = nn.Conv2d(128, 128, 3, padding=1)

        self.conv3a = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, 3, padding=1)

        self.conv4a = nn.Conv2d(256, 512, 3, padding=1)
        self.conv4b = nn.Conv2d(512, 512, 3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.bn1a = nn.BatchNorm2d(64)
        self.bn1b = nn.BatchNorm2d(64)

        self.bn2a = nn.BatchNorm2d(128)
        self.bn2b = nn.BatchNorm2d(128)

        self.bn3a = nn.BatchNorm2d(256)
        self.bn3b = nn.BatchNorm2d(256)

        self.bn4a = nn.BatchNorm2d(512)
        self.bn4b = nn.BatchNorm2d(512)

        self.lin1 = nn.Linear(512 * 2 * 2, 4096)
        self.lin2 = nn.Linear(4096, 4096)

        self.drop = nn.Dropout(p=drop)

    def forward(self, x):
        x = F.relu(self.bn1a(self.conv1a(x)))
        x = F.relu(self.bn1b(self.conv1b(x)))
        x = self.pool(x)

        x = F.relu(self.bn2a(self.conv2a(x)))
        x = F.relu(self.bn2b(self.conv2b(x)))
        x = self.pool(x)

        x = F.relu(self.bn3a(self.conv3a(x)))
        x = F.relu(self.bn3b(self.conv3b(x)))
        x = self.pool(x)

        x = F.relu(self.bn4a(self.conv4a(x)))
        x = F.relu(self.bn4b(self.conv4b(x)))
        x = self.pool(x)
        # print(x.shape)

        x = x.view(-1, 512 * 2 * 2)
        x = F.relu(self.drop(self.lin1(x)))
        x = F.relu(self.drop(self.lin2(x)))

        return x


class Vgg(VggFeatures):
    def __init__(self, drop=0.2):
        super().__init__(drop)
        self.lin3 = nn.Linear(4096, 7)

    def forward(self, x):
        x = super().forward(x)
        x = self.lin3(x)
        return x

# %%
#from models import vgg, efn
#nets = {
#    'vgg': vgg.Vgg,
#    'efn': efn.EfficientNet
#}


def setup_network(hps):
    #net = nets[hps['network']]()
    net = Vgg()

    # Prepare logger
    logger = Logger()
    if hps['restore_epoch']:
        restore(net, logger, hps)

    return logger, net

# %%
def run(net, logger, hps):
    # Create dataloaders
    trainloader, valloader, testloader = get_dataloaders(bs=hps['bs'])

    net = net.to(device)

    learning_rate = float(hps['lr'])
    scaler = GradScaler()

    # optimizer = torch.optim.Adadelta(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adagrad(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0.0001, amsgrad=True)
    # optimizer = torch.optim.ASGD(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)

    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.75, patience=5, verbose=True)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 20, gamma=0.5, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(trainloader), epochs=hps['n_epochs'])
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=1e-6, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6, last_epoch=-1, verbose=False)
    criterion = nn.CrossEntropyLoss()

    best_acc = 0.0

    print("Training", hps['name'], "on", device)
    for epoch in range(hps['start_epoch'], hps['n_epochs']):

        acc_tr, loss_tr = train(net, trainloader, criterion, optimizer, scaler)
        logger.loss_train.append(loss_tr)
        logger.acc_train.append(acc_tr)

        acc_v, loss_v = evaluate(net, valloader, criterion)
        logger.loss_val.append(loss_v)
        logger.acc_val.append(acc_v)

        # Update learning rate
        scheduler.step(acc_v)

        if acc_v > best_acc:
            best_acc = acc_v

            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        if (epoch + 1) % hps['save_freq'] == 0:
            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        print('Epoch %2d' % (epoch + 1),
              'Train Accuracy: %2.4f %%' % acc_tr,
              'Val Accuracy: %2.4f %%' % acc_v,
              sep='\t\t')

    # Calculate performance on test set
    acc_test, loss_test = evaluate(net, testloader, criterion)
    print('Test Accuracy: %2.4f %%' % acc_test,
          'Test Loss: %2.6f' % loss_test,
          sep='\t\t')

# %%
logger, net = setup_network(hps)
net
# Out:
# Vgg(
#   (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4a): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4b): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bn1a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2a): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2b): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3a): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3b): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4a): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4b): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lin1): Linear(in_features=2048, out_features=4096, bias=True)
#   (lin2): Linear(in_features=4096, out_features=4096, bias=True)
#   (drop): Dropout(p=0.2, inplace=False)
#   (lin3): Linear(in_features=4096, out_features=7, bias=True)
# )

# %%
run(net, logger, hps)
# Out:
# Training myvgg on cuda:0
# Epoch  1		Train Accuracy: 33.3728 %		Val Accuracy: 42.7138 %
# Epoch  2		Train Accuracy: 47.4235 %		Val Accuracy: 54.6392 %
# Epoch  3		Train Accuracy: 52.2509 %		Val Accuracy: 59.9053 %
# Epoch  4		Train Accuracy: 55.3394 %		Val Accuracy: 57.9827 %
# Epoch  5		Train Accuracy: 56.9494 %		Val Accuracy: 60.0167 %
# Epoch  6		Train Accuracy: 58.3388 %		Val Accuracy: 63.4160 %
# Epoch  7		Train Accuracy: 59.7144 %		Val Accuracy: 62.7194 %
# Epoch  8		Train Accuracy: 60.5793 %		Val Accuracy: 63.3881 %
# Epoch  9		Train Accuracy: 61.6504 %		Val Accuracy: 65.5893 %
# Epoch 10		Train Accuracy: 62.3157 %		Val Accuracy: 65.6729 %
# Epoch 11		Train Accuracy: 63.2930 %		Val Accuracy: 65.2828 %
# Epoch 12		Train Accuracy: 63.7964 %		Val Accuracy: 65.5614 %
# Epoch 13		Train Accuracy: 64.2798 %		Val Accuracy: 67.5954 %
# Epoch 14		Train Accuracy: 65.0653 %		Val Accuracy: 67.2053 %
# Epoch 15		Train Accuracy: 65.7560 %		Val Accuracy: 67.4004 %
# Epoch 16		Train Accuracy: 66.5147 %		Val Accuracy: 67.0660 %
# Epoch 17		Train Accuracy: 66.9665 %		Val Accuracy: 66.4809 %
# Epoch 18		Train Accuracy: 67.4600 %		Val Accuracy: 68.5985 %
# Epoch 19		Train Accuracy: 68.0675 %		Val Accuracy: 67.3168 %
# Epoch 20		Train Accuracy: 68.6429 %		Val Accuracy: 68.7935 %
# Epoch 21		Train Accuracy: 69.1389 %		Val Accuracy: 67.6790 %
# Epoch 22		Train Accuracy: 69.7440 %		Val Accuracy: 68.8214 %
# Epoch 23		Train Accuracy: 70.4351 %		Val Accuracy: 66.0072 %
# Epoch 24		Train Accuracy: 70.9694 %		Val Accuracy: 68.1806 %
# Epoch 25		Train Accuracy: 71.4072 %		Val Accuracy: 69.1000 %
# Epoch 26		Train Accuracy: 71.9283 %		Val Accuracy: 69.4344 %
# Epoch 27		Train Accuracy: 72.5344 %		Val Accuracy: 66.0908 %
# Epoch 28		Train Accuracy: 72.8012 %		Val Accuracy: 68.7099 %
# Epoch 29		Train Accuracy: 73.4049 %		Val Accuracy: 66.2023 %
# Epoch 30		Train Accuracy: 73.9987 %		Val Accuracy: 68.5428 %
# Epoch 31		Train Accuracy: 74.5651 %		Val Accuracy: 68.3199 %
# Epoch    32: reducing learning rate of group 0 to 7.5000e-03.
# Epoch 32		Train Accuracy: 74.9528 %		Val Accuracy: 68.6542 %
# Epoch 33		Train Accuracy: 76.7449 %		Val Accuracy: 69.7966 %
# Epoch 34		Train Accuracy: 77.1702 %		Val Accuracy: 70.7718 %
# Epoch 35		Train Accuracy: 77.7711 %		Val Accuracy: 71.1619 %
# Epoch 36		Train Accuracy: 78.1410 %		Val Accuracy: 70.8833 %
# Epoch 37		Train Accuracy: 78.7049 %		Val Accuracy: 70.5489 %
# Epoch 38		Train Accuracy: 79.2257 %		Val Accuracy: 70.3817 %
# Epoch 39		Train Accuracy: 79.3984 %		Val Accuracy: 69.2115 %
# Epoch 40		Train Accuracy: 79.7656 %		Val Accuracy: 69.1279 %
# Epoch 41		Train Accuracy: 80.1773 %		Val Accuracy: 71.3848 %
# Epoch 42		Train Accuracy: 80.6548 %		Val Accuracy: 71.9978 %
# Epoch 43		Train Accuracy: 81.0091 %		Val Accuracy: 71.6634 %
# Epoch 44		Train Accuracy: 81.2992 %		Val Accuracy: 71.5520 %
# Epoch 45		Train Accuracy: 81.7207 %		Val Accuracy: 71.4962 %
# Epoch 46		Train Accuracy: 82.1711 %		Val Accuracy: 71.0504 %
# Epoch 47		Train Accuracy: 82.4672 %		Val Accuracy: 72.1371 %
# Epoch 48		Train Accuracy: 82.8566 %		Val Accuracy: 71.4962 %
# Epoch 49		Train Accuracy: 82.7538 %		Val Accuracy: 71.3569 %
# Epoch 50		Train Accuracy: 83.4484 %		Val Accuracy: 71.6913 %
# Epoch 51		Train Accuracy: 83.8228 %		Val Accuracy: 70.2424 %
# Epoch 52		Train Accuracy: 84.0308 %		Val Accuracy: 71.6356 %
# Epoch    53: reducing learning rate of group 0 to 5.6250e-03.
# Epoch 53		Train Accuracy: 84.3168 %		Val Accuracy: 71.2455 %
# Epoch 54		Train Accuracy: 85.7358 %		Val Accuracy: 70.9947 %
# Epoch 55		Train Accuracy: 86.1141 %		Val Accuracy: 70.7997 %
# Epoch 56		Train Accuracy: 86.4809 %		Val Accuracy: 71.8585 %
# Epoch 57		Train Accuracy: 86.7885 %		Val Accuracy: 71.5520 %
# Epoch 58		Train Accuracy: 86.9274 %		Val Accuracy: 71.0783 %
# Epoch    59: reducing learning rate of group 0 to 4.2188e-03.
# Epoch 59		Train Accuracy: 87.1270 %		Val Accuracy: 71.3569 %
# Epoch 60		Train Accuracy: 88.1337 %		Val Accuracy: 71.6077 %
# Epoch 61		Train Accuracy: 88.4503 %		Val Accuracy: 71.9420 %
# Epoch 62		Train Accuracy: 88.6349 %		Val Accuracy: 73.0287 %
# Epoch 63		Train Accuracy: 88.7927 %		Val Accuracy: 71.3569 %
# Epoch 64		Train Accuracy: 88.9369 %		Val Accuracy: 72.7501 %
# Epoch 65		Train Accuracy: 89.0184 %		Val Accuracy: 71.9420 %
# Epoch 66		Train Accuracy: 89.2044 %		Val Accuracy: 72.2764 %
# Epoch 67		Train Accuracy: 89.2497 %		Val Accuracy: 72.1649 %
# Epoch    68: reducing learning rate of group 0 to 3.1641e-03.
# Epoch 68		Train Accuracy: 89.6127 %		Val Accuracy: 72.0256 %
# Epoch 69		Train Accuracy: 90.2703 %		Val Accuracy: 72.4993 %
# Epoch 70		Train Accuracy: 90.3567 %		Val Accuracy: 72.5829 %
# Epoch 71		Train Accuracy: 90.4507 %		Val Accuracy: 72.2764 %
# Epoch 72		Train Accuracy: 90.6155 %		Val Accuracy: 72.7779 %
# Epoch 73		Train Accuracy: 90.7489 %		Val Accuracy: 72.9730 %
# Epoch    74: reducing learning rate of group 0 to 2.3730e-03.
# Epoch 74		Train Accuracy: 90.8635 %		Val Accuracy: 72.1649 %
# Epoch 75		Train Accuracy: 91.2714 %		Val Accuracy: 73.2795 %
# Epoch 76		Train Accuracy: 91.3275 %		Val Accuracy: 73.2795 %
# Epoch 77		Train Accuracy: 91.5277 %		Val Accuracy: 73.0287 %
# Epoch 78		Train Accuracy: 91.6789 %		Val Accuracy: 73.0008 %
# Epoch 79		Train Accuracy: 91.8085 %		Val Accuracy: 73.0844 %
# Epoch 80		Train Accuracy: 91.7507 %		Val Accuracy: 72.5829 %
# Epoch    81: reducing learning rate of group 0 to 1.7798e-03.
# Epoch 81		Train Accuracy: 91.7019 %		Val Accuracy: 73.0008 %
# Epoch 82		Train Accuracy: 92.1662 %		Val Accuracy: 73.1123 %
# Epoch 83		Train Accuracy: 92.3174 %		Val Accuracy: 72.9451 %
# Epoch 84		Train Accuracy: 92.3439 %		Val Accuracy: 72.9172 %
# Epoch 85		Train Accuracy: 92.4181 %		Val Accuracy: 73.0287 %
# Epoch 86		Train Accuracy: 92.3965 %		Val Accuracy: 73.5024 %
# Epoch 87		Train Accuracy: 92.4048 %		Val Accuracy: 73.3352 %
# Epoch 88		Train Accuracy: 92.5793 %		Val Accuracy: 72.4993 %
# Epoch 89		Train Accuracy: 92.5065 %		Val Accuracy: 73.2237 %
# Epoch 90		Train Accuracy: 92.6682 %		Val Accuracy: 72.9451 %
# Epoch 91		Train Accuracy: 92.6246 %		Val Accuracy: 73.0566 %
# Epoch    92: reducing learning rate of group 0 to 1.3348e-03.
# Epoch 92		Train Accuracy: 92.7204 %		Val Accuracy: 73.3073 %
# Epoch 93		Train Accuracy: 92.9409 %		Val Accuracy: 72.8337 %
# Epoch 94		Train Accuracy: 92.9942 %		Val Accuracy: 73.1402 %
# Epoch 95		Train Accuracy: 93.0534 %		Val Accuracy: 73.3073 %
# Epoch 96		Train Accuracy: 93.1436 %		Val Accuracy: 73.1959 %
# Epoch 97		Train Accuracy: 92.9928 %		Val Accuracy: 72.8337 %
# Epoch    98: reducing learning rate of group 0 to 1.0011e-03.
# Epoch 98		Train Accuracy: 93.1865 %		Val Accuracy: 73.4188 %
# Epoch 99		Train Accuracy: 93.3324 %		Val Accuracy: 73.3352 %
# Epoch 100		Train Accuracy: 93.2770 %		Val Accuracy: 73.1402 %
# Epoch 101		Train Accuracy: 93.4233 %		Val Accuracy: 73.1402 %
# Epoch 102		Train Accuracy: 93.4763 %		Val Accuracy: 72.8615 %
# Epoch 103		Train Accuracy: 93.5066 %		Val Accuracy: 72.8058 %
# Epoch   104: reducing learning rate of group 0 to 7.5085e-04.
# Epoch 104		Train Accuracy: 93.5473 %		Val Accuracy: 73.0287 %
# Epoch 105		Train Accuracy: 93.7981 %		Val Accuracy: 72.8894 %
# Epoch 106		Train Accuracy: 93.7055 %		Val Accuracy: 73.0566 %
# Epoch 107		Train Accuracy: 93.5916 %		Val Accuracy: 73.1680 %
# Epoch 108		Train Accuracy: 93.6504 %		Val Accuracy: 73.6138 %
# Epoch 109		Train Accuracy: 93.6985 %		Val Accuracy: 73.0566 %
# Epoch 110		Train Accuracy: 93.6633 %		Val Accuracy: 72.9172 %
# Epoch 111		Train Accuracy: 93.7093 %		Val Accuracy: 73.0287 %
# Epoch 112		Train Accuracy: 93.7988 %		Val Accuracy: 73.4466 %
# Epoch 113		Train Accuracy: 93.7911 %		Val Accuracy: 72.6943 %
# Epoch   114: reducing learning rate of group 0 to 5.6314e-04.
# Epoch 114		Train Accuracy: 93.8100 %		Val Accuracy: 73.0844 %
# Epoch 115		Train Accuracy: 93.7706 %		Val Accuracy: 73.2516 %
# Epoch 116		Train Accuracy: 94.0395 %		Val Accuracy: 72.8615 %
# Epoch 117		Train Accuracy: 94.0451 %		Val Accuracy: 73.3909 %
# Epoch 118		Train Accuracy: 94.0068 %		Val Accuracy: 73.2237 %
# Epoch 119		Train Accuracy: 94.0566 %		Val Accuracy: 73.5581 %
# Epoch   120: reducing learning rate of group 0 to 4.2235e-04.
# Epoch 120		Train Accuracy: 93.9371 %		Val Accuracy: 73.2516 %
# Epoch 121		Train Accuracy: 94.1349 %		Val Accuracy: 73.1123 %
# Epoch 122		Train Accuracy: 94.2063 %		Val Accuracy: 73.0844 %
# Epoch 123		Train Accuracy: 94.1517 %		Val Accuracy: 73.3631 %
# Epoch 124		Train Accuracy: 94.0527 %		Val Accuracy: 73.3073 %
# Epoch 125		Train Accuracy: 94.2004 %		Val Accuracy: 73.4466 %
# Epoch   126: reducing learning rate of group 0 to 3.1676e-04.
# Epoch 126		Train Accuracy: 94.1534 %		Val Accuracy: 73.5024 %
# Epoch 127		Train Accuracy: 94.1259 %		Val Accuracy: 73.3909 %
# Epoch 128		Train Accuracy: 94.2851 %		Val Accuracy: 73.4188 %
# Epoch 129		Train Accuracy: 94.2095 %		Val Accuracy: 73.3909 %
# Epoch 130		Train Accuracy: 94.1687 %		Val Accuracy: 73.3909 %
# Epoch 131		Train Accuracy: 94.3161 %		Val Accuracy: 73.3909 %
# Epoch   132: reducing learning rate of group 0 to 2.3757e-04.
# Epoch 132		Train Accuracy: 94.1851 %		Val Accuracy: 73.5302 %
# Epoch 133		Train Accuracy: 94.2474 %		Val Accuracy: 73.4188 %
# Epoch 134		Train Accuracy: 94.2704 %		Val Accuracy: 73.2516 %
# Epoch 135		Train Accuracy: 94.2990 %		Val Accuracy: 73.1680 %
# Epoch 136		Train Accuracy: 94.3614 %		Val Accuracy: 73.3909 %
# Epoch 137		Train Accuracy: 94.3774 %		Val Accuracy: 73.2516 %
# Epoch   138: reducing learning rate of group 0 to 1.7818e-04.
# Epoch 138		Train Accuracy: 94.3373 %		Val Accuracy: 73.0566 %
# Epoch 139		Train Accuracy: 94.3868 %		Val Accuracy: 73.2516 %
# Epoch 140		Train Accuracy: 94.4150 %		Val Accuracy: 73.3909 %
# Epoch 141		Train Accuracy: 94.3652 %		Val Accuracy: 72.9730 %
# Epoch 142		Train Accuracy: 94.3732 %		Val Accuracy: 73.4188 %
# Epoch 143		Train Accuracy: 94.3422 %		Val Accuracy: 73.2516 %
# Epoch   144: reducing learning rate of group 0 to 1.3363e-04.
# Epoch 144		Train Accuracy: 94.3770 %		Val Accuracy: 73.0844 %
# Epoch 145		Train Accuracy: 94.4697 %		Val Accuracy: 73.0008 %
# Epoch 146		Train Accuracy: 94.4989 %		Val Accuracy: 73.3073 %
# Epoch 147		Train Accuracy: 94.4470 %		Val Accuracy: 73.3909 %
# Epoch 148		Train Accuracy: 94.5550 %		Val Accuracy: 73.2516 %
# Epoch 149		Train Accuracy: 94.4554 %		Val Accuracy: 73.2795 %
# Epoch   150: reducing learning rate of group 0 to 1.0023e-04.
# Epoch 150		Train Accuracy: 94.5780 %		Val Accuracy: 73.2516 %
# Epoch 151		Train Accuracy: 94.5059 %		Val Accuracy: 73.1680 %
# Epoch 152		Train Accuracy: 94.4718 %		Val Accuracy: 73.3631 %
# Epoch 153		Train Accuracy: 94.4202 %		Val Accuracy: 73.3909 %
# Epoch 154		Train Accuracy: 94.4777 %		Val Accuracy: 73.1959 %
# Epoch 155		Train Accuracy: 94.4610 %		Val Accuracy: 73.3073 %
# Epoch   156: reducing learning rate of group 0 to 7.5169e-05.
# Epoch 156		Train Accuracy: 94.4512 %		Val Accuracy: 73.3352 %
# Epoch 157		Train Accuracy: 94.4509 %		Val Accuracy: 73.2795 %
# Epoch 158		Train Accuracy: 94.5944 %		Val Accuracy: 73.2516 %
# Epoch 159		Train Accuracy: 94.4902 %		Val Accuracy: 73.3073 %
# Epoch 160		Train Accuracy: 94.5888 %		Val Accuracy: 73.2795 %
# Epoch 161		Train Accuracy: 94.5393 %		Val Accuracy: 73.3352 %
# Epoch   162: reducing learning rate of group 0 to 5.6377e-05.
# Epoch 162		Train Accuracy: 94.4220 %		Val Accuracy: 73.2237 %
# Epoch 163		Train Accuracy: 94.5804 %		Val Accuracy: 73.1959 %
# Epoch 164		Train Accuracy: 94.4871 %		Val Accuracy: 73.3631 %
# Epoch 165		Train Accuracy: 94.5122 %		Val Accuracy: 73.1959 %
# Epoch 166		Train Accuracy: 94.6219 %		Val Accuracy: 73.1680 %
# Epoch 167		Train Accuracy: 94.5143 %		Val Accuracy: 73.3073 %
# Epoch   168: reducing learning rate of group 0 to 4.2283e-05.
# Epoch 168		Train Accuracy: 94.5251 %		Val Accuracy: 73.0566 %
# Epoch 169		Train Accuracy: 94.5477 %		Val Accuracy: 73.2237 %
# Epoch 170		Train Accuracy: 94.5219 %		Val Accuracy: 73.1959 %
# Epoch 171		Train Accuracy: 94.6219 %		Val Accuracy: 73.2237 %
# Epoch 172		Train Accuracy: 94.6341 %		Val Accuracy: 73.1959 %
# Epoch 173		Train Accuracy: 94.6017 %		Val Accuracy: 73.4466 %
# Epoch   174: reducing learning rate of group 0 to 3.1712e-05.
# Epoch 174		Train Accuracy: 94.5926 %		Val Accuracy: 73.2516 %
# Epoch 175		Train Accuracy: 94.4742 %		Val Accuracy: 73.4188 %
# Epoch 176		Train Accuracy: 94.6048 %		Val Accuracy: 73.3352 %
# Epoch 177		Train Accuracy: 94.4881 %		Val Accuracy: 73.2237 %
# Epoch 178		Train Accuracy: 94.5557 %		Val Accuracy: 73.2237 %
# Epoch 179		Train Accuracy: 94.5352 %		Val Accuracy: 73.3073 %
# Epoch   180: reducing learning rate of group 0 to 2.3784e-05.
# Epoch 180		Train Accuracy: 94.5989 %		Val Accuracy: 73.4188 %
# Epoch 181		Train Accuracy: 94.5219 %		Val Accuracy: 73.4466 %
# Epoch 182		Train Accuracy: 94.5616 %		Val Accuracy: 73.2516 %
# Epoch 183		Train Accuracy: 94.6118 %		Val Accuracy: 73.2795 %
# Epoch 184		Train Accuracy: 94.3669 %		Val Accuracy: 73.3073 %
# Epoch 185		Train Accuracy: 94.5735 %		Val Accuracy: 73.4466 %
# Epoch   186: reducing learning rate of group 0 to 1.7838e-05.
# Epoch 186		Train Accuracy: 94.6156 %		Val Accuracy: 73.4188 %
# Epoch 187		Train Accuracy: 94.6069 %		Val Accuracy: 73.3352 %
# Epoch 188		Train Accuracy: 94.6167 %		Val Accuracy: 73.3631 %
# Epoch 189		Train Accuracy: 94.6797 %		Val Accuracy: 73.1680 %
# Epoch 190		Train Accuracy: 94.5122 %		Val Accuracy: 73.3352 %
# Epoch 191		Train Accuracy: 94.6000 %		Val Accuracy: 73.3631 %
# Epoch   192: reducing learning rate of group 0 to 1.3379e-05.
# Epoch 192		Train Accuracy: 94.5777 %		Val Accuracy: 73.3909 %
# Epoch 193		Train Accuracy: 94.6470 %		Val Accuracy: 73.3073 %
# Epoch 194		Train Accuracy: 94.5791 %		Val Accuracy: 73.3631 %
# Epoch 195		Train Accuracy: 94.4878 %		Val Accuracy: 73.3631 %
# Epoch 196		Train Accuracy: 94.5937 %		Val Accuracy: 73.4188 %
# Epoch 197		Train Accuracy: 94.6139 %		Val Accuracy: 73.2516 %
# Epoch   198: reducing learning rate of group 0 to 1.0034e-05.
# Epoch 198		Train Accuracy: 94.5669 %		Val Accuracy: 73.3909 %
# Epoch 199		Train Accuracy: 94.5592 %		Val Accuracy: 73.2795 %
# Epoch 200		Train Accuracy: 94.6355 %		Val Accuracy: 73.3352 %
# Epoch 201		Train Accuracy: 94.5317 %		Val Accuracy: 73.3909 %
# Epoch 202		Train Accuracy: 94.5157 %		Val Accuracy: 73.2795 %
# Epoch 203		Train Accuracy: 94.6397 %		Val Accuracy: 73.3909 %
# Epoch   204: reducing learning rate of group 0 to 7.5254e-06.
# Epoch 204		Train Accuracy: 94.5630 %		Val Accuracy: 73.4466 %
# Epoch 205		Train Accuracy: 94.5794 %		Val Accuracy: 73.3073 %
# Epoch 206		Train Accuracy: 94.6303 %		Val Accuracy: 73.4745 %
# Epoch 207		Train Accuracy: 94.6006 %		Val Accuracy: 73.4745 %
# Epoch 208		Train Accuracy: 94.5268 %		Val Accuracy: 73.5024 %
# Epoch 209		Train Accuracy: 94.5111 %		Val Accuracy: 73.3073 %
# Epoch   210: reducing learning rate of group 0 to 5.6441e-06.
# Epoch 210		Train Accuracy: 94.5481 %		Val Accuracy: 73.5581 %
# Epoch 211		Train Accuracy: 94.5989 %		Val Accuracy: 73.4745 %
# Epoch 212		Train Accuracy: 94.5655 %		Val Accuracy: 73.2795 %
# Epoch 213		Train Accuracy: 94.5230 %		Val Accuracy: 73.4745 %
# Epoch 214		Train Accuracy: 94.6512 %		Val Accuracy: 73.3631 %
# Epoch 215		Train Accuracy: 94.6031 %		Val Accuracy: 73.1959 %
# Epoch   216: reducing learning rate of group 0 to 4.2331e-06.
# Epoch 216		Train Accuracy: 94.6247 %		Val Accuracy: 73.1959 %
# Epoch 217		Train Accuracy: 94.6620 %		Val Accuracy: 73.3352 %
# Epoch 218		Train Accuracy: 94.7013 %		Val Accuracy: 73.3073 %
# Epoch 219		Train Accuracy: 94.7142 %		Val Accuracy: 73.5302 %
# Epoch 220		Train Accuracy: 94.6135 %		Val Accuracy: 73.3073 %
# Epoch 221		Train Accuracy: 94.6094 %		Val Accuracy: 73.5302 %
# Epoch   222: reducing learning rate of group 0 to 3.1748e-06.
# Epoch 222		Train Accuracy: 94.5515 %		Val Accuracy: 73.3631 %
# Epoch 223		Train Accuracy: 94.5449 %		Val Accuracy: 73.3073 %
# Epoch 224		Train Accuracy: 94.6327 %		Val Accuracy: 73.3909 %
# Epoch 225		Train Accuracy: 94.6940 %		Val Accuracy: 73.2516 %
# Epoch 226		Train Accuracy: 94.5700 %		Val Accuracy: 73.5302 %
# Epoch 227		Train Accuracy: 94.5658 %		Val Accuracy: 73.2795 %
# Epoch   228: reducing learning rate of group 0 to 2.3811e-06.
# Epoch 228		Train Accuracy: 94.6296 %		Val Accuracy: 73.3352 %
# Epoch 229		Train Accuracy: 94.5223 %		Val Accuracy: 73.3631 %
# Epoch 230		Train Accuracy: 94.5669 %		Val Accuracy: 73.5024 %
# Epoch 231		Train Accuracy: 94.6289 %		Val Accuracy: 73.4188 %
# Epoch 232		Train Accuracy: 94.6195 %		Val Accuracy: 73.3909 %
# Epoch 233		Train Accuracy: 94.6783 %		Val Accuracy: 73.3909 %
# Epoch   234: reducing learning rate of group 0 to 1.7858e-06.
# Epoch 234		Train Accuracy: 94.5794 %		Val Accuracy: 73.3631 %
# Epoch 235		Train Accuracy: 94.6135 %		Val Accuracy: 73.4188 %
# Epoch 236		Train Accuracy: 94.6188 %		Val Accuracy: 73.3073 %
# Epoch 237		Train Accuracy: 94.6024 %		Val Accuracy: 73.4466 %
# Epoch 238		Train Accuracy: 94.5355 %		Val Accuracy: 73.2795 %
# Epoch 239		Train Accuracy: 94.4906 %		Val Accuracy: 73.4188 %
# Epoch   240: reducing learning rate of group 0 to 1.3394e-06.
# Epoch 240		Train Accuracy: 94.6930 %		Val Accuracy: 73.3909 %
# Epoch 241		Train Accuracy: 94.5818 %		Val Accuracy: 73.3909 %
# Epoch 242		Train Accuracy: 94.6198 %		Val Accuracy: 73.4188 %
# Epoch 243		Train Accuracy: 94.6498 %		Val Accuracy: 73.1680 %
# Epoch 244		Train Accuracy: 94.5700 %		Val Accuracy: 73.1680 %
# Epoch 245		Train Accuracy: 94.5373 %		Val Accuracy: 73.4466 %
# Epoch   246: reducing learning rate of group 0 to 1.0045e-06.
# Epoch 246		Train Accuracy: 94.6919 %		Val Accuracy: 73.4466 %
# Epoch 247		Train Accuracy: 94.6299 %		Val Accuracy: 73.3631 %
# Epoch 248		Train Accuracy: 94.5292 %		Val Accuracy: 73.4188 %
# Epoch 249		Train Accuracy: 94.5575 %		Val Accuracy: 73.3631 %
# Epoch 250		Train Accuracy: 94.5195 %		Val Accuracy: 73.3352 %
# Epoch 251		Train Accuracy: 94.4955 %		Val Accuracy: 73.4745 %
# Epoch   252: reducing learning rate of group 0 to 7.5339e-07.
# Epoch 252		Train Accuracy: 94.6104 %		Val Accuracy: 73.3631 %
# Epoch 253		Train Accuracy: 94.6323 %		Val Accuracy: 73.5024 %
# Epoch 254		Train Accuracy: 94.6010 %		Val Accuracy: 73.2795 %
# Epoch 255		Train Accuracy: 94.6344 %		Val Accuracy: 73.4188 %
# Epoch 256		Train Accuracy: 94.6696 %		Val Accuracy: 73.4466 %
# Epoch 257		Train Accuracy: 94.5923 %		Val Accuracy: 73.4188 %
# Epoch   258: reducing learning rate of group 0 to 5.6504e-07.
# Epoch 258		Train Accuracy: 94.6825 %		Val Accuracy: 73.4745 %
# Epoch 259		Train Accuracy: 94.4603 %		Val Accuracy: 73.3352 %
# Epoch 260		Train Accuracy: 94.5331 %		Val Accuracy: 73.3631 %
# Epoch 261		Train Accuracy: 94.5432 %		Val Accuracy: 73.4188 %
# Epoch 262		Train Accuracy: 94.6595 %		Val Accuracy: 73.4745 %
# Epoch 263		Train Accuracy: 94.6905 %		Val Accuracy: 73.5024 %
# Epoch   264: reducing learning rate of group 0 to 4.2378e-07.
# Epoch 264		Train Accuracy: 94.6640 %		Val Accuracy: 73.5302 %
# Epoch 265		Train Accuracy: 94.6250 %		Val Accuracy: 73.3909 %
# Epoch 266		Train Accuracy: 94.5609 %		Val Accuracy: 73.2516 %
# Epoch 267		Train Accuracy: 94.5878 %		Val Accuracy: 73.4188 %
# Epoch 268		Train Accuracy: 94.6400 %		Val Accuracy: 73.1123 %
# Epoch 269		Train Accuracy: 94.6299 %		Val Accuracy: 73.4466 %
# Epoch   270: reducing learning rate of group 0 to 3.1784e-07.
# Epoch 270		Train Accuracy: 94.4892 %		Val Accuracy: 73.3352 %
# Epoch 271		Train Accuracy: 94.6167 %		Val Accuracy: 73.3352 %
# Epoch 272		Train Accuracy: 94.5498 %		Val Accuracy: 73.3352 %
# Epoch 273		Train Accuracy: 94.4909 %		Val Accuracy: 73.3909 %
# Epoch 274		Train Accuracy: 94.4927 %		Val Accuracy: 73.4466 %
# Epoch 275		Train Accuracy: 94.4902 %		Val Accuracy: 73.3631 %
# Epoch   276: reducing learning rate of group 0 to 2.3838e-07.
# Epoch 276		Train Accuracy: 94.6146 %		Val Accuracy: 73.4188 %
# Epoch 277		Train Accuracy: 94.5306 %		Val Accuracy: 73.2795 %
# Epoch 278		Train Accuracy: 94.6240 %		Val Accuracy: 73.5024 %
# Epoch 279		Train Accuracy: 94.5979 %		Val Accuracy: 73.4466 %
# Epoch 280		Train Accuracy: 94.5937 %		Val Accuracy: 73.4745 %
# Epoch 281		Train Accuracy: 94.6602 %		Val Accuracy: 73.3909 %
# Epoch   282: reducing learning rate of group 0 to 1.7878e-07.
# Epoch 282		Train Accuracy: 94.5519 %		Val Accuracy: 73.3352 %
# Epoch 283		Train Accuracy: 94.6003 %		Val Accuracy: 73.2516 %
# Epoch 284		Train Accuracy: 94.6254 %		Val Accuracy: 73.3352 %
# Epoch 285		Train Accuracy: 94.6839 %		Val Accuracy: 73.3631 %
# Epoch 286		Train Accuracy: 94.6306 %		Val Accuracy: 73.6417 %
# Epoch 287		Train Accuracy: 94.6661 %		Val Accuracy: 73.2795 %
# Epoch 288		Train Accuracy: 94.6285 %		Val Accuracy: 73.4188 %
# Epoch 289		Train Accuracy: 94.6055 %		Val Accuracy: 73.3631 %
# Epoch 290		Train Accuracy: 94.5467 %		Val Accuracy: 73.4188 %
# Epoch 291		Train Accuracy: 94.5533 %		Val Accuracy: 73.4466 %
# Epoch   292: reducing learning rate of group 0 to 1.3409e-07.
# Epoch 292		Train Accuracy: 94.6842 %		Val Accuracy: 73.5302 %
# Epoch 293		Train Accuracy: 94.5749 %		Val Accuracy: 73.4188 %
# Epoch 294		Train Accuracy: 94.6052 %		Val Accuracy: 73.3073 %
# Epoch 295		Train Accuracy: 94.6337 %		Val Accuracy: 73.4745 %
# Epoch 296		Train Accuracy: 94.6888 %		Val Accuracy: 73.3909 %
# Epoch 297		Train Accuracy: 94.5822 %		Val Accuracy: 73.3631 %
# Epoch   298: reducing learning rate of group 0 to 1.0057e-07.
# Epoch 298		Train Accuracy: 94.6146 %		Val Accuracy: 73.3352 %
# Epoch 299		Train Accuracy: 94.5944 %		Val Accuracy: 73.4188 %
# Epoch 300		Train Accuracy: 94.6226 %		Val Accuracy: 73.5024 %
# Test Accuracy: 72.0256 %		Test Loss: 0.026825

# %%
hps = {
    'network': 'vgg',  # which network do you want to train
    'name': 'myvgg',  # whatever you want to name your run
    'n_epochs': 50,
    'model_save_dir': None,  # where will checkpoints be stored (path created automatically using hps[name])
    'restore_epoch': None,  # continue training from a specific saved point
    'start_epoch': 0,
    'lr': 0.0001,  # starting learning rate
    'save_freq': 20,  # how often to create checkpoints
    'drop': 0.1,
    'bs': 64,
}
hps['model_save_dir'] = os.path.join(os.getcwd(), 'vgg_fine_tuning/checkpoint', hps['name'])

if not os.path.exists(hps['model_save_dir']):
    os.makedirs(hps['model_save_dir'])
def run(net, logger, hps):
    # Create dataloaders
    trainloader, valloader, testloader = get_dataloaders(bs=hps['bs'])

    net = net.to(device)

    learning_rate = float(hps['lr'])
    scaler = GradScaler()

    # optimizer = torch.optim.Adadelta(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adagrad(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0.0001, amsgrad=True)
    # optimizer = torch.optim.ASGD(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)

#     scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.75, patience=5, verbose=True)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 20, gamma=0.5, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(trainloader), epochs=hps['n_epochs'])
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=1e-6, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6, last_epoch=-1, verbose=False)
    criterion = nn.CrossEntropyLoss()

    best_acc = 0.0

    print("Training", hps['name'], "on", device)
    for epoch in range(hps['start_epoch'], hps['n_epochs']):

        acc_tr, loss_tr = train(net, trainloader, criterion, optimizer, scaler)
        logger.loss_train.append(loss_tr)
        logger.acc_train.append(acc_tr)

        acc_v, loss_v = evaluate(net, valloader, criterion)
        logger.loss_val.append(loss_v)
        logger.acc_val.append(acc_v)

        # Update learning rate
#         scheduler.step(acc_v)

        if acc_v > best_acc:
            best_acc = acc_v

            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        if (epoch + 1) % hps['save_freq'] == 0:
            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        print('Epoch %2d' % (epoch + 1),
              'Train Accuracy: %2.4f %%' % acc_tr,
              'Val Accuracy: %2.4f %%' % acc_v,
              sep='\t\t')

    # Calculate performance on test set
    acc_test, loss_test = evaluate(net, testloader, criterion)
    print('Test Accuracy: %2.4f %%' % acc_test,
          'Test Loss: %2.6f' % loss_test,
          sep='\t\t')

# %%
run(net, logger, hps)
# Out:
# Training myvgg on cuda:0
# Epoch  1		Train Accuracy: 94.5951 %		Val Accuracy: 73.2516 %
# Epoch  2		Train Accuracy: 94.5348 %		Val Accuracy: 73.4745 %
# Epoch  3		Train Accuracy: 94.5324 %		Val Accuracy: 73.3352 %
# Epoch  4		Train Accuracy: 94.5362 %		Val Accuracy: 73.5024 %
# Epoch  5		Train Accuracy: 94.5881 %		Val Accuracy: 73.2237 %
# Epoch  6		Train Accuracy: 94.5268 %		Val Accuracy: 73.0844 %
# Epoch  7		Train Accuracy: 94.6006 %		Val Accuracy: 73.3909 %
# Epoch  8		Train Accuracy: 94.6348 %		Val Accuracy: 73.3909 %
# Epoch  9		Train Accuracy: 94.4927 %		Val Accuracy: 73.1959 %
# Epoch 10		Train Accuracy: 94.6588 %		Val Accuracy: 73.0844 %
# Epoch 11		Train Accuracy: 94.6498 %		Val Accuracy: 73.3352 %
# Epoch 12		Train Accuracy: 94.5460 %		Val Accuracy: 73.4745 %
# Epoch 13		Train Accuracy: 94.5090 %		Val Accuracy: 73.1959 %
# Epoch 14		Train Accuracy: 94.6195 %		Val Accuracy: 73.3909 %
# Epoch 15		Train Accuracy: 94.5759 %		Val Accuracy: 73.2237 %
# Epoch 16		Train Accuracy: 94.5470 %		Val Accuracy: 73.5024 %
# Epoch 17		Train Accuracy: 94.5756 %		Val Accuracy: 73.4188 %
# Epoch 18		Train Accuracy: 94.5860 %		Val Accuracy: 73.4188 %
# Epoch 19		Train Accuracy: 94.6027 %		Val Accuracy: 73.3631 %
# Epoch 20		Train Accuracy: 94.6209 %		Val Accuracy: 73.5581 %
# Epoch 21		Train Accuracy: 94.6978 %		Val Accuracy: 73.3909 %
# Epoch 22		Train Accuracy: 94.5825 %		Val Accuracy: 73.3909 %
# Epoch 23		Train Accuracy: 94.6428 %		Val Accuracy: 73.4188 %
# Epoch 24		Train Accuracy: 94.6209 %		Val Accuracy: 73.3352 %
# Epoch 25		Train Accuracy: 94.6142 %		Val Accuracy: 73.4466 %
# Epoch 26		Train Accuracy: 94.5714 %		Val Accuracy: 73.3352 %
# Epoch 27		Train Accuracy: 94.6316 %		Val Accuracy: 73.4466 %
# Epoch 28		Train Accuracy: 94.6633 %		Val Accuracy: 73.3631 %
# Epoch 29		Train Accuracy: 94.5853 %		Val Accuracy: 73.5024 %
# Epoch 30		Train Accuracy: 94.6585 %		Val Accuracy: 73.3909 %
# Epoch 31		Train Accuracy: 94.6658 %		Val Accuracy: 73.2795 %
# Epoch 32		Train Accuracy: 94.6759 %		Val Accuracy: 73.3352 %
# Epoch 33		Train Accuracy: 94.6801 %		Val Accuracy: 73.3073 %
# Epoch 34		Train Accuracy: 94.6794 %		Val Accuracy: 73.4466 %
# Epoch 35		Train Accuracy: 94.7529 %		Val Accuracy: 73.4466 %
# Epoch 36		Train Accuracy: 94.6153 %		Val Accuracy: 73.3631 %
# Epoch 37		Train Accuracy: 94.7044 %		Val Accuracy: 73.4188 %
# Epoch 38		Train Accuracy: 94.6557 %		Val Accuracy: 73.3352 %
# Epoch 39		Train Accuracy: 94.5926 %		Val Accuracy: 73.5860 %
# Epoch 40		Train Accuracy: 94.6717 %		Val Accuracy: 73.4188 %
# Epoch 41		Train Accuracy: 94.6177 %		Val Accuracy: 73.2795 %
# Epoch 42		Train Accuracy: 94.7487 %		Val Accuracy: 73.2237 %
# Epoch 43		Train Accuracy: 94.7407 %		Val Accuracy: 73.3073 %
# Epoch 44		Train Accuracy: 94.5763 %		Val Accuracy: 73.4466 %
# Epoch 45		Train Accuracy: 94.6595 %		Val Accuracy: 73.3352 %
# Epoch 46		Train Accuracy: 94.7428 %		Val Accuracy: 73.3073 %
# Epoch 47		Train Accuracy: 94.6397 %		Val Accuracy: 73.5024 %
# Epoch 48		Train Accuracy: 94.6703 %		Val Accuracy: 73.4466 %
# Epoch 49		Train Accuracy: 94.6738 %		Val Accuracy: 73.4745 %
# Epoch 50		Train Accuracy: 94.7595 %		Val Accuracy: 73.3909 %
# Test Accuracy: 72.0535 %		Test Loss: 0.027874
