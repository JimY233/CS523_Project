# %%
# !pip install timm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /usr3/graduate/jiamingy/.local/lib/python3.8/site-packages (0.4.9)
# Requirement already satisfied: torch>=1.4 in /share/pkg.7/pytorch/1.8.1/install/lib/python3.8/site-packages (from timm) (1.8.1+cu111)
# Requirement already satisfied: torchvision in /share/pkg.7/pytorch/1.8.1/install/lib/python3.8/site-packages (from timm) (0.9.1+cu111)
# Requirement already satisfied: typing-extensions in /share/pkg.7/python3/3.8.6/install/lib/python3.8/site-packages (from torch>=1.4->timm) (3.7.4.3)
# Requirement already satisfied: numpy in /share/pkg.7/tensorflow/2.3.1/install/lib/python3.8/site-packages (from torch>=1.4->timm) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /share/pkg.7/python3/3.8.6/install/lib/python3.8/site-packages (from torchvision->timm) (8.0.1)
# WARNING: You are using pip version 20.2.4; however, version 21.1.2 is available.
# You should consider upgrading via the '/share/pkg.7/python3/3.8.6/install/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import sys
import warnings

import torch
import torch.nn as nn
from torch.cuda.amp import GradScaler
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
import numpy as np
import pandas as pd
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from PIL import Image
from torch.utils.data import Dataset
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None, augment=False):
        self.images = images
        self.labels = labels
        self.transform = transform

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img = np.array(self.images[idx])

        img = Image.fromarray(img)

        if self.transform:
            img = self.transform(img)

        label = torch.tensor(self.labels[idx]).type(torch.long)
        sample = (img, label)

        return sample
    
def load_data(path='datasets/fer2013/fer2013.csv'):
    fer2013 = pd.read_csv(path)
    emotion_mapping = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}

    return fer2013, emotion_mapping


def prepare_data(data):
    """ Prepare data for modeling
        input: data frame with labels und pixel data
        output: image and label array """

    image_array = np.zeros(shape=(len(data), 48, 48))
    image_label = np.array(list(map(int, data['emotion'])))

    for i, row in enumerate(data.index):
        image = np.fromstring(data.loc[row, 'pixels'], dtype=int, sep=' ')
        image = np.reshape(image, (48, 48))
        image_array[i] = image

    return image_array, image_label

def get_dataloaders(path='datasets/fer2013/fer2013.csv', bs=64, augment=True):
    """ Prepare train, val, & test dataloaders
        Augment training data using:
            - cropping
            - shifting (vertical/horizental)
            - horizental flipping
            - rotation

        input: path to fer2013 csv file
        output: (Dataloader, Dataloader, Dataloader) """

    fer2013, emotion_mapping = load_data(path)

    xtrain, ytrain = prepare_data(fer2013[fer2013['Usage'] == 'Training'])
    xval, yval = prepare_data(fer2013[fer2013['Usage'] == 'PrivateTest'])
    xtest, ytest = prepare_data(fer2013[fer2013['Usage'] == 'PublicTest'])

    mu, st = 0, 255

    test_transform = transforms.Compose([
        # transforms.Scale(52),
        transforms.TenCrop(40),
        transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
        transforms.Lambda(lambda tensors: torch.stack([transforms.Normalize(mean=(mu,), std=(st,))(t) for t in tensors])),
    ])

    if augment:
        train_transform = transforms.Compose([
            transforms.RandomResizedCrop(48, scale=(0.8, 1.2)),
            transforms.RandomApply([transforms.RandomAffine(0, translate=(0.2, 0.2))], p=0.5),
            transforms.RandomHorizontalFlip(),
            transforms.RandomApply([transforms.RandomRotation(10)], p=0.5),

            transforms.TenCrop(40),
            transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
            transforms.Lambda(lambda tensors: torch.stack([transforms.Normalize(mean=(mu,), std=(st,))(t) for t in tensors])),
            transforms.Lambda(lambda tensors: torch.stack([transforms.RandomErasing(p=0.5)(t) for t in tensors])),
        ])
    else:
        train_transform = test_transform

    # X = np.vstack((xtrain, xval))
    # Y = np.hstack((ytrain, yval))

    train = CustomDataset(xtrain, ytrain, train_transform)
    val = CustomDataset(xval, yval, test_transform)
    test = CustomDataset(xtest, ytest, test_transform)

    trainloader = DataLoader(train, batch_size=bs, shuffle=True, num_workers=2)
    valloader = DataLoader(val, batch_size=64, shuffle=True, num_workers=2)
    testloader = DataLoader(test, batch_size=64, shuffle=True, num_workers=2)

    return trainloader, valloader, testloader

# %%
import os
def save(net, logger, hps, epoch):
    # Create the path the checkpint will be saved at using the epoch number
    path = os.path.join(hps['model_save_dir'], 'epoch_' + str(epoch))

    # create a dictionary containing the logger info and model info that will be saved
    checkpoint = {
        'logs': logger.get_logs(),
        'params': net.state_dict()
    }

    # save checkpoint
    torch.save(checkpoint, path)


def restore(net, logger, hps):
    """ Load back the model and logger from a given checkpoint
        epoch detailed in hps['restore_epoch'], if available"""
    path = os.path.join(hps['model_save_dir'], 'epoch_' + str(hps['restore_epoch']))

    if os.path.exists(path):
        try:
            checkpoint = torch.load(path)

            logger.restore_logs(checkpoint['logs'])
            net.load_state_dict(checkpoint['params'])
            print("Network Restored!")

        except Exception as e:
            print("Restore Failed! Training from scratch.")
            print(e)
            hps['start_epoch'] = 0

    else:
        print("Restore point unavailable. Training from scratch.")
        hps['start_epoch'] = 0


def load_features(model, params):
    """ Load params into all layers of 'model'
        that are compatible, then freeze them"""
    model_dict = model.state_dict()

    imp_params = {k: v for k, v in params.items() if k in model_dict}

    # Load layers
    model_dict.update(imp_params)
    model.load_state_dict(imp_params)

    # Freeze layers
    for name, param in model.named_parameters():
        param.requires_grad = False

# %%
hps = {
    'network': 'vgg',  # which network do you want to train
    'name': 'myvgg',  # whatever you want to name your run
    'n_epochs': 300,
    'model_save_dir': None,  # where will checkpoints be stored (path created automatically using hps[name])
    'restore_epoch': None,  # continue training from a specific saved point
    'start_epoch': 0,
    'lr': 0.01,  # starting learning rate
    'save_freq': 20,  # how often to create checkpoints
    'drop': 0.1,
    'bs': 64,
}
hps['model_save_dir'] = os.path.join(os.getcwd(), 'vggcheckpoints', hps['name'])

if not os.path.exists(hps['model_save_dir']):
    os.makedirs(hps['model_save_dir'])

# %%
from torch.cuda.amp import autocast

warnings.filterwarnings("ignore")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def train(net, dataloader, criterion, optimizer, scaler, Ncrop=True):
    net = net.train()
    loss_tr, correct_count, n_samples = 0.0, 0.0, 0.0
    iters = len(dataloader)  # number of batches, not images

    for i, data in enumerate(dataloader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        with autocast():
            if Ncrop:
                # fuse crops and batchsize
                bs, ncrops, c, h, w = inputs.shape
                inputs = inputs.view(-1, c, h, w)

            # repeat labels ncrops times
            labels = torch.repeat_interleave(labels, repeats=ncrops, dim=0)

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            scaler.scale(loss).backward()

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            # scheduler.step(epoch + i / iters)

            # calculate performance metrics
            loss_tr += loss.item()

            _, preds = torch.max(outputs.data, 1)
            correct_count += (preds == labels).sum().item()
            n_samples += labels.size(0)

    acc = 100 * correct_count / n_samples
    loss = loss_tr / n_samples

    return acc, loss


def evaluate(net, dataloader, criterion, Ncrop=True):
    net = net.eval()
    loss_tr, correct_count, n_samples = 0.0, 0.0, 0.0
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        if Ncrop:
            # fuse crops and batchsize
            bs, ncrops, c, h, w = inputs.shape
            inputs = inputs.view(-1, c, h, w)
            # forward
            outputs = net(inputs)
            # combine results across the crops
            outputs = outputs.view(bs, ncrops, -1)
            outputs = torch.sum(outputs, dim=1) / ncrops
        else:
            outputs = net(inputs)

        loss = criterion(outputs, labels)

        # calculate performance metrics
        loss_tr += loss.item()

        _, preds = torch.max(outputs.data, 1)
        correct_count += (preds == labels).sum().item()
        n_samples += labels.size(0)

    acc = 100 * correct_count / n_samples
    loss = loss_tr / n_samples

    return acc, loss

# %%
from matplotlib import pyplot as plt

class Logger:
    def __init__(self):
        self.loss_train = []
        self.loss_val = []

        self.acc_train = []
        self.acc_val = []

    def get_logs(self):
        return self.loss_train, self.loss_val, self.acc_train, self.acc_val

    def restore_logs(self, logs):
        self.loss_train, self.loss_val, self.acc_train, self.acc_val = logs

    def save_plt(self, hps):
        loss_path = os.path.join(hps['model_save_dir'], 'loss.jpg')
        acc_path = os.path.join(hps['model_save_dir'], 'acc.jpg')

        plt.figure()
        plt.plot(self.acc_train, 'g', label='Training Acc')
        plt.plot(self.acc_val, 'b', label='Validation Acc')
        plt.title('Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Acc')
        plt.legend()
        plt.grid()
        plt.savefig(acc_path)

        plt.figure()
        plt.plot(self.loss_train, 'g', label='Training Loss')
        plt.plot(self.loss_val, 'b', label='Validation Loss')
        plt.title('Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid()
        plt.savefig(loss_path)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torchvision

class VggFeatures(nn.Module):
    def __init__(self, drop=0.2):
        super().__init__()

        self.conv1a = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1)
        self.conv1b = nn.Conv2d(64, out_channels=64, kernel_size=3, padding=1)

        self.conv2a = nn.Conv2d(64, 128, 3, padding=1)
        self.conv2b = nn.Conv2d(128, 128, 3, padding=1)

        self.conv3a = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, 3, padding=1)

        self.conv4a = nn.Conv2d(256, 512, 3, padding=1)
        self.conv4b = nn.Conv2d(512, 512, 3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.bn1a = nn.BatchNorm2d(64)
        self.bn1b = nn.BatchNorm2d(64)

        self.bn2a = nn.BatchNorm2d(128)
        self.bn2b = nn.BatchNorm2d(128)

        self.bn3a = nn.BatchNorm2d(256)
        self.bn3b = nn.BatchNorm2d(256)

        self.bn4a = nn.BatchNorm2d(512)
        self.bn4b = nn.BatchNorm2d(512)

        self.lin1 = nn.Linear(512 * 2 * 2, 4096)
        self.lin2 = nn.Linear(4096, 4096)

        self.drop = nn.Dropout(p=drop)

    def forward(self, x):
        x = F.relu(self.bn1a(self.conv1a(x)))
        x = F.relu(self.bn1b(self.conv1b(x)))
        x = self.pool(x)

        x = F.relu(self.bn2a(self.conv2a(x)))
        x = F.relu(self.bn2b(self.conv2b(x)))
        x = self.pool(x)

        x = F.relu(self.bn3a(self.conv3a(x)))
        x = F.relu(self.bn3b(self.conv3b(x)))
        x = self.pool(x)

        x = F.relu(self.bn4a(self.conv4a(x)))
        x = F.relu(self.bn4b(self.conv4b(x)))
        x = self.pool(x)
        # print(x.shape)

        x = x.view(-1, 512 * 2 * 2)
        x = F.relu(self.drop(self.lin1(x)))
        x = F.relu(self.drop(self.lin2(x)))

        return x


class Vgg(VggFeatures):
    def __init__(self, drop=0.2):
        super().__init__(drop)
        self.lin3 = nn.Linear(4096, 7)

    def forward(self, x):
        x = super().forward(x)
        x = self.lin3(x)
        return x

# %%
import timm

class EfficientNet(nn.Module):
    def __init__(self, pretrained=True, drop=0.1):
        super().__init__()
        self.model = timm.create_model('tf_efficientnet_b3_ns', pretrained=pretrained)
        n_features = self.model.classifier.in_features
        self.model.classifier = nn.Linear(n_features, 7)

    def forward(self, x):
        # print(x.shape)
        x = x.repeat(1, 3, 1, 1)
        # print(x.shape)
        
        x = self.model(x)
        return x
# Out:
# MESSAGE FROM RCS: Setting LC_ALL and LANG to locale value 'en_US.utf8'.  If you wish to use a different locale, use the following code to set it to your prefered locale prior to importing click.
# ###############################
# import os
# os.environ["LC_ALL"]="new locale"
# os.environ["LANG"]=os.environ["LC_ALL"]
# ###############################

# %%
#from models import vgg, efn
#nets = {
#    'vgg': vgg.Vgg,
#    'efn': efn.EfficientNet
#}


def setup_network(hps):
    #net = nets[hps['network']]()
    net = Vgg()

    # Prepare logger
    logger = Logger()
    if hps['restore_epoch']:
        restore(net, logger, hps)

    return logger, net

# %%
def run(net, logger, hps):
    # Create dataloaders
    trainloader, valloader, testloader = get_dataloaders(bs=hps['bs'])

    net = net.to(device)

    learning_rate = float(hps['lr'])
    scaler = GradScaler()

    # optimizer = torch.optim.Adadelta(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adagrad(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0.0001, amsgrad=True)
    # optimizer = torch.optim.ASGD(net.parameters(), lr=learning_rate, weight_decay=0.0001)
    optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)

    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.75, patience=5, verbose=True)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 20, gamma=0.5, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(trainloader), epochs=hps['n_epochs'])
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=1e-6, last_epoch=-1, verbose=True)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6, last_epoch=-1, verbose=False)
    criterion = nn.CrossEntropyLoss()

    best_acc = 0.0

    print("Training", hps['name'], "on", device)
    for epoch in range(hps['start_epoch'], hps['n_epochs']):

        acc_tr, loss_tr = train(net, trainloader, criterion, optimizer, scaler)
        logger.loss_train.append(loss_tr)
        logger.acc_train.append(acc_tr)

        acc_v, loss_v = evaluate(net, valloader, criterion)
        logger.loss_val.append(loss_v)
        logger.acc_val.append(acc_v)

        # Update learning rate
        scheduler.step(acc_v)

        if acc_v > best_acc:
            best_acc = acc_v

            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        if (epoch + 1) % hps['save_freq'] == 0:
            save(net, logger, hps, epoch + 1)
            logger.save_plt(hps)

        print('Epoch %2d' % (epoch + 1),
              'Train Accuracy: %2.4f %%' % acc_tr,
              'Val Accuracy: %2.4f %%' % acc_v,
              sep='\t\t')

    # Calculate performance on test set
    acc_test, loss_test = evaluate(net, testloader, criterion)
    print('Test Accuracy: %2.4f %%' % acc_test,
          'Test Loss: %2.6f' % loss_test,
          sep='\t\t')

# %%
logger, net = setup_network(hps)
net
# Out:
# Vgg(
#   (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4a): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4b): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bn1a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2a): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2b): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3a): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3b): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4a): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4b): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lin1): Linear(in_features=2048, out_features=4096, bias=True)
#   (lin2): Linear(in_features=4096, out_features=4096, bias=True)
#   (drop): Dropout(p=0.2, inplace=False)
#   (lin3): Linear(in_features=4096, out_features=7, bias=True)
# )

# %%
run(net, logger, hps)
# Out:
# Training myvgg on cuda:0
# Epoch  1		Train Accuracy: 33.2331 %		Val Accuracy: 46.0574 %
# Epoch  2		Train Accuracy: 47.5259 %		Val Accuracy: 51.7693 %
# Epoch  3		Train Accuracy: 52.2937 %		Val Accuracy: 57.0911 %
# Epoch  4		Train Accuracy: 54.8278 %		Val Accuracy: 61.2705 %
# Epoch  5		Train Accuracy: 57.0204 %		Val Accuracy: 60.3511 %
# Epoch  6		Train Accuracy: 58.0849 %		Val Accuracy: 63.2210 %
# Epoch  7		Train Accuracy: 59.3859 %		Val Accuracy: 63.7782 %
# Epoch  8		Train Accuracy: 60.4511 %		Val Accuracy: 63.6668 %
# Epoch  9		Train Accuracy: 61.2564 %		Val Accuracy: 63.6668 %
# Epoch 10		Train Accuracy: 62.1502 %		Val Accuracy: 65.7008 %
# Epoch 11		Train Accuracy: 63.0043 %		Val Accuracy: 64.9763 %
# Epoch 12		Train Accuracy: 63.8211 %		Val Accuracy: 66.1466 %
# Epoch 13		Train Accuracy: 64.3526 %		Val Accuracy: 65.1714 %
# Epoch 14		Train Accuracy: 64.9417 %		Val Accuracy: 65.8679 %
# Epoch 15		Train Accuracy: 65.6383 %		Val Accuracy: 66.4531 %
# Epoch 16		Train Accuracy: 66.3841 %		Val Accuracy: 66.9824 %
# Epoch 17		Train Accuracy: 66.9752 %		Val Accuracy: 66.8153 %
# Epoch 18		Train Accuracy: 67.5868 %		Val Accuracy: 66.3416 %
# Epoch 19		Train Accuracy: 68.2232 %		Val Accuracy: 65.9237 %
# Epoch 20		Train Accuracy: 68.3883 %		Val Accuracy: 68.2084 %
# Epoch 21		Train Accuracy: 69.0874 %		Val Accuracy: 68.8493 %
# Epoch 22		Train Accuracy: 69.7551 %		Val Accuracy: 66.8710 %
# Epoch 23		Train Accuracy: 70.2100 %		Val Accuracy: 69.2115 %
# Epoch 24		Train Accuracy: 70.8865 %		Val Accuracy: 69.1558 %
# Epoch 25		Train Accuracy: 71.3860 %		Val Accuracy: 68.4313 %
# Epoch 26		Train Accuracy: 71.8238 %		Val Accuracy: 68.0691 %
# Epoch 27		Train Accuracy: 72.3707 %		Val Accuracy: 68.1527 %
# Epoch 28		Train Accuracy: 72.9322 %		Val Accuracy: 68.4592 %
# Epoch 29		Train Accuracy: 73.3808 %		Val Accuracy: 69.7687 %
# Epoch 30		Train Accuracy: 74.1767 %		Val Accuracy: 68.5149 %
# Epoch 31		Train Accuracy: 74.4359 %		Val Accuracy: 66.0908 %
# Epoch 32		Train Accuracy: 74.9173 %		Val Accuracy: 68.7378 %
# Epoch 33		Train Accuracy: 75.4997 %		Val Accuracy: 69.6851 %
# Epoch 34		Train Accuracy: 76.1469 %		Val Accuracy: 70.3539 %
# Epoch 35		Train Accuracy: 76.5749 %		Val Accuracy: 70.7439 %
# Epoch 36		Train Accuracy: 77.0159 %		Val Accuracy: 69.8523 %
# Epoch 37		Train Accuracy: 77.5266 %		Val Accuracy: 70.6046 %
# Epoch 38		Train Accuracy: 78.1508 %		Val Accuracy: 70.7161 %
# Epoch 39		Train Accuracy: 78.4294 %		Val Accuracy: 71.4962 %
# Epoch 40		Train Accuracy: 78.8422 %		Val Accuracy: 68.5706 %
# Epoch 41		Train Accuracy: 79.4528 %		Val Accuracy: 70.0474 %
# Epoch 42		Train Accuracy: 79.7266 %		Val Accuracy: 69.8523 %
# Epoch 43		Train Accuracy: 80.0129 %		Val Accuracy: 70.2145 %
# Epoch 44		Train Accuracy: 80.5793 %		Val Accuracy: 72.3321 %
# Epoch 45		Train Accuracy: 81.1233 %		Val Accuracy: 70.1588 %
# Epoch 46		Train Accuracy: 81.4017 %		Val Accuracy: 71.6913 %
# Epoch 47		Train Accuracy: 81.8538 %		Val Accuracy: 71.2455 %
# Epoch 48		Train Accuracy: 82.2397 %		Val Accuracy: 71.1897 %
# Epoch 49		Train Accuracy: 82.7643 %		Val Accuracy: 71.2455 %
# Epoch    50: reducing learning rate of group 0 to 7.5000e-03.
# Epoch 50		Train Accuracy: 82.8973 %		Val Accuracy: 70.7997 %
# Epoch 51		Train Accuracy: 84.6041 %		Val Accuracy: 71.8863 %
# Epoch 52		Train Accuracy: 85.0500 %		Val Accuracy: 72.5272 %
# Epoch 53		Train Accuracy: 85.6035 %		Val Accuracy: 71.8585 %
# Epoch 54		Train Accuracy: 85.6784 %		Val Accuracy: 71.7470 %
# Epoch 55		Train Accuracy: 86.2096 %		Val Accuracy: 71.4405 %
# Epoch 56		Train Accuracy: 86.3524 %		Val Accuracy: 71.8863 %
# Epoch 57		Train Accuracy: 86.4269 %		Val Accuracy: 71.4405 %
# Epoch 58		Train Accuracy: 86.6770 %		Val Accuracy: 72.8058 %
# Epoch 59		Train Accuracy: 86.8017 %		Val Accuracy: 70.2981 %
# Epoch 60		Train Accuracy: 87.2361 %		Val Accuracy: 71.8306 %
# Epoch 61		Train Accuracy: 87.4200 %		Val Accuracy: 71.4405 %
# Epoch 62		Train Accuracy: 87.5590 %		Val Accuracy: 72.6386 %
# Epoch 63		Train Accuracy: 87.9010 %		Val Accuracy: 72.1649 %
# Epoch    64: reducing learning rate of group 0 to 5.6250e-03.
# Epoch 64		Train Accuracy: 87.7854 %		Val Accuracy: 72.8058 %
# Epoch 65		Train Accuracy: 89.0376 %		Val Accuracy: 72.8894 %
# Epoch 66		Train Accuracy: 89.4072 %		Val Accuracy: 72.7779 %
# Epoch 67		Train Accuracy: 89.4190 %		Val Accuracy: 73.0287 %
# Epoch 68		Train Accuracy: 89.6848 %		Val Accuracy: 72.1928 %
# Epoch 69		Train Accuracy: 89.9321 %		Val Accuracy: 73.1959 %
# Epoch 70		Train Accuracy: 89.7705 %		Val Accuracy: 72.7501 %
# Epoch 71		Train Accuracy: 90.1707 %		Val Accuracy: 72.6386 %
# Epoch 72		Train Accuracy: 90.0289 %		Val Accuracy: 72.4993 %
# Epoch 73		Train Accuracy: 90.3421 %		Val Accuracy: 73.1680 %
# Epoch 74		Train Accuracy: 90.4546 %		Val Accuracy: 72.5550 %
# Epoch    75: reducing learning rate of group 0 to 4.2188e-03.
# Epoch 75		Train Accuracy: 90.4027 %		Val Accuracy: 72.6665 %
# Epoch 76		Train Accuracy: 91.1697 %		Val Accuracy: 73.1680 %
# Epoch 77		Train Accuracy: 91.3484 %		Val Accuracy: 72.7222 %
# Epoch 78		Train Accuracy: 91.5546 %		Val Accuracy: 73.0566 %
# Epoch 79		Train Accuracy: 91.5654 %		Val Accuracy: 72.4993 %
# Epoch 80		Train Accuracy: 91.6458 %		Val Accuracy: 73.0287 %
# Epoch    81: reducing learning rate of group 0 to 3.1641e-03.
# Epoch 81		Train Accuracy: 91.6789 %		Val Accuracy: 72.5272 %
# Epoch 82		Train Accuracy: 92.3543 %		Val Accuracy: 73.4466 %
# Epoch 83		Train Accuracy: 92.4048 %		Val Accuracy: 73.1123 %
# Epoch 84		Train Accuracy: 92.3787 %		Val Accuracy: 73.2795 %
# Epoch 85		Train Accuracy: 92.5884 %		Val Accuracy: 73.1959 %
# Epoch 86		Train Accuracy: 92.6260 %		Val Accuracy: 72.9730 %
# Epoch 87		Train Accuracy: 92.7246 %		Val Accuracy: 72.6943 %
# Epoch    88: reducing learning rate of group 0 to 2.3730e-03.
# Epoch 88		Train Accuracy: 92.7768 %		Val Accuracy: 73.0287 %
# Epoch 89		Train Accuracy: 93.0147 %		Val Accuracy: 73.3909 %
# Epoch 90		Train Accuracy: 93.2195 %		Val Accuracy: 72.3879 %
# Epoch 91		Train Accuracy: 93.2237 %		Val Accuracy: 73.1959 %
# Epoch 92		Train Accuracy: 93.2606 %		Val Accuracy: 73.0566 %
# Epoch 93		Train Accuracy: 93.2829 %		Val Accuracy: 72.9172 %
# Epoch    94: reducing learning rate of group 0 to 1.7798e-03.
# Epoch 94		Train Accuracy: 93.4017 %		Val Accuracy: 73.2516 %
# Epoch 95		Train Accuracy: 93.5463 %		Val Accuracy: 73.4188 %
# Epoch 96		Train Accuracy: 93.5522 %		Val Accuracy: 73.8924 %
# Epoch 97		Train Accuracy: 93.6839 %		Val Accuracy: 73.2516 %
# Epoch 98		Train Accuracy: 93.8472 %		Val Accuracy: 73.2237 %
# Epoch 99		Train Accuracy: 93.9127 %		Val Accuracy: 73.9760 %
# Epoch 100		Train Accuracy: 93.8371 %		Val Accuracy: 73.4466 %
# Epoch 101		Train Accuracy: 93.9204 %		Val Accuracy: 73.2516 %
# Epoch 102		Train Accuracy: 93.8542 %		Val Accuracy: 73.2516 %
# Epoch 103		Train Accuracy: 93.8075 %		Val Accuracy: 73.1680 %
# Epoch 104		Train Accuracy: 93.9044 %		Val Accuracy: 73.6695 %
# Epoch   105: reducing learning rate of group 0 to 1.3348e-03.
# Epoch 105		Train Accuracy: 93.9263 %		Val Accuracy: 73.2795 %
# Epoch 106		Train Accuracy: 94.0684 %		Val Accuracy: 73.6417 %
# Epoch 107		Train Accuracy: 94.2659 %		Val Accuracy: 73.0844 %
# Epoch 108		Train Accuracy: 94.1753 %		Val Accuracy: 73.5024 %
# Epoch 109		Train Accuracy: 94.2168 %		Val Accuracy: 73.2795 %
# Epoch 110		Train Accuracy: 94.2889 %		Val Accuracy: 73.4745 %
# Epoch   111: reducing learning rate of group 0 to 1.0011e-03.
# Epoch 111		Train Accuracy: 94.3450 %		Val Accuracy: 73.6417 %
# Epoch 112		Train Accuracy: 94.3387 %		Val Accuracy: 73.6138 %
# Epoch 113		Train Accuracy: 94.4056 %		Val Accuracy: 73.9482 %
# Epoch 114		Train Accuracy: 94.4272 %		Val Accuracy: 73.8924 %
# Epoch 115		Train Accuracy: 94.4443 %		Val Accuracy: 73.6138 %
# Epoch 116		Train Accuracy: 94.5139 %		Val Accuracy: 73.5024 %
# Epoch   117: reducing learning rate of group 0 to 7.5085e-04.
# Epoch 117		Train Accuracy: 94.4557 %		Val Accuracy: 73.4745 %
# Epoch 118		Train Accuracy: 94.5905 %		Val Accuracy: 73.7253 %
# Epoch 119		Train Accuracy: 94.6222 %		Val Accuracy: 73.5860 %
# Epoch 120		Train Accuracy: 94.6174 %		Val Accuracy: 73.6417 %
# Epoch 121		Train Accuracy: 94.6891 %		Val Accuracy: 73.4466 %
# Epoch 122		Train Accuracy: 94.6316 %		Val Accuracy: 74.3104 %
# Epoch 123		Train Accuracy: 94.7058 %		Val Accuracy: 74.0596 %
# Epoch 124		Train Accuracy: 94.6543 %		Val Accuracy: 73.8089 %
# Epoch 125		Train Accuracy: 94.7121 %		Val Accuracy: 73.8367 %
# Epoch 126		Train Accuracy: 94.7853 %		Val Accuracy: 73.7531 %
# Epoch 127		Train Accuracy: 94.7856 %		Val Accuracy: 73.7531 %
# Epoch   128: reducing learning rate of group 0 to 5.6314e-04.
# Epoch 128		Train Accuracy: 94.7633 %		Val Accuracy: 73.6138 %
# Epoch 129		Train Accuracy: 94.8180 %		Val Accuracy: 74.1989 %
# Epoch 130		Train Accuracy: 94.8814 %		Val Accuracy: 73.6974 %
# Epoch 131		Train Accuracy: 94.8967 %		Val Accuracy: 73.7253 %
# Epoch 132		Train Accuracy: 94.9382 %		Val Accuracy: 73.5302 %
# Epoch 133		Train Accuracy: 94.9242 %		Val Accuracy: 73.7531 %
# Epoch   134: reducing learning rate of group 0 to 4.2235e-04.
# Epoch 134		Train Accuracy: 94.8142 %		Val Accuracy: 73.6974 %
# Epoch 135		Train Accuracy: 94.9256 %		Val Accuracy: 73.3352 %
# Epoch 136		Train Accuracy: 94.9497 %		Val Accuracy: 73.3909 %
# Epoch 137		Train Accuracy: 94.9988 %		Val Accuracy: 73.8089 %
# Epoch 138		Train Accuracy: 95.0413 %		Val Accuracy: 73.8646 %
# Epoch 139		Train Accuracy: 94.9915 %		Val Accuracy: 74.0039 %
# Epoch   140: reducing learning rate of group 0 to 3.1676e-04.
# Epoch 140		Train Accuracy: 95.0110 %		Val Accuracy: 73.6695 %
# Epoch 141		Train Accuracy: 95.0883 %		Val Accuracy: 73.6138 %
# Epoch 142		Train Accuracy: 95.0103 %		Val Accuracy: 73.8089 %
# Epoch 143		Train Accuracy: 95.1263 %		Val Accuracy: 73.8646 %
# Epoch 144		Train Accuracy: 95.1169 %		Val Accuracy: 73.7253 %
# Epoch 145		Train Accuracy: 95.1015 %		Val Accuracy: 73.7810 %
# Epoch   146: reducing learning rate of group 0 to 2.3757e-04.
# Epoch 146		Train Accuracy: 95.0559 %		Val Accuracy: 74.0318 %
# Epoch 147		Train Accuracy: 95.1346 %		Val Accuracy: 74.0596 %
# Epoch 148		Train Accuracy: 95.0772 %		Val Accuracy: 73.8089 %
# Epoch 149		Train Accuracy: 95.1500 %		Val Accuracy: 74.1432 %
# Epoch 150		Train Accuracy: 95.1210 %		Val Accuracy: 74.1711 %
# Epoch 151		Train Accuracy: 95.1325 %		Val Accuracy: 73.7810 %
# Epoch   152: reducing learning rate of group 0 to 1.7818e-04.
# Epoch 152		Train Accuracy: 95.0935 %		Val Accuracy: 73.7253 %
# Epoch 153		Train Accuracy: 95.1865 %		Val Accuracy: 73.9203 %
# Epoch 154		Train Accuracy: 95.0691 %		Val Accuracy: 73.8924 %
# Epoch 155		Train Accuracy: 95.1263 %		Val Accuracy: 73.6417 %
# Epoch 156		Train Accuracy: 95.2245 %		Val Accuracy: 73.8924 %
# Epoch 157		Train Accuracy: 95.1399 %		Val Accuracy: 73.8089 %
# Epoch   158: reducing learning rate of group 0 to 1.3363e-04.
# Epoch 158		Train Accuracy: 95.1830 %		Val Accuracy: 73.6138 %
# Epoch 159		Train Accuracy: 95.1203 %		Val Accuracy: 73.5581 %
# Epoch 160		Train Accuracy: 95.1973 %		Val Accuracy: 73.6417 %
# Epoch 161		Train Accuracy: 95.2217 %		Val Accuracy: 73.5581 %
# Epoch 162		Train Accuracy: 95.1075 %		Val Accuracy: 73.9203 %
# Epoch 163		Train Accuracy: 95.2276 %		Val Accuracy: 73.6974 %
# Epoch   164: reducing learning rate of group 0 to 1.0023e-04.
# Epoch 164		Train Accuracy: 95.2837 %		Val Accuracy: 73.8367 %
# Epoch 165		Train Accuracy: 95.2370 %		Val Accuracy: 73.7810 %
# Epoch 166		Train Accuracy: 95.2088 %		Val Accuracy: 73.9760 %
# Epoch 167		Train Accuracy: 95.2391 %		Val Accuracy: 74.0039 %
# Epoch 168		Train Accuracy: 95.2384 %		Val Accuracy: 73.6695 %
# Epoch 169		Train Accuracy: 95.1952 %		Val Accuracy: 73.9760 %
# Epoch   170: reducing learning rate of group 0 to 7.5169e-05.
# Epoch 170		Train Accuracy: 95.2081 %		Val Accuracy: 73.9203 %
# Epoch 171		Train Accuracy: 95.2137 %		Val Accuracy: 73.8646 %
# Epoch 172		Train Accuracy: 95.1715 %		Val Accuracy: 73.9203 %
# Epoch 173		Train Accuracy: 95.3304 %		Val Accuracy: 73.6138 %
# Epoch 174		Train Accuracy: 95.3241 %		Val Accuracy: 73.8089 %
# Epoch 175		Train Accuracy: 95.2342 %		Val Accuracy: 73.7531 %
# Epoch   176: reducing learning rate of group 0 to 5.6377e-05.
# Epoch 176		Train Accuracy: 95.2980 %		Val Accuracy: 73.8367 %
# Epoch 177		Train Accuracy: 95.2416 %		Val Accuracy: 73.6417 %
# Epoch 178		Train Accuracy: 95.2440 %		Val Accuracy: 73.8646 %
# Epoch 179		Train Accuracy: 95.1914 %		Val Accuracy: 73.7531 %
# Epoch 180		Train Accuracy: 95.3102 %		Val Accuracy: 73.7253 %
# Epoch 181		Train Accuracy: 95.2287 %		Val Accuracy: 73.6138 %
# Epoch   182: reducing learning rate of group 0 to 4.2283e-05.
# Epoch 182		Train Accuracy: 95.3757 %		Val Accuracy: 73.5024 %
# Epoch 183		Train Accuracy: 95.2060 %		Val Accuracy: 73.6695 %
# Epoch 184		Train Accuracy: 95.3314 %		Val Accuracy: 73.6974 %
# Epoch 185		Train Accuracy: 95.2837 %		Val Accuracy: 73.9203 %
# Epoch 186		Train Accuracy: 95.1949 %		Val Accuracy: 73.9482 %
# Epoch 187		Train Accuracy: 95.2851 %		Val Accuracy: 73.7253 %
# Epoch   188: reducing learning rate of group 0 to 3.1712e-05.
# Epoch 188		Train Accuracy: 95.3074 %		Val Accuracy: 73.7531 %
# Epoch 189		Train Accuracy: 95.3245 %		Val Accuracy: 73.9760 %
# Epoch 190		Train Accuracy: 95.2830 %		Val Accuracy: 73.9203 %
# Epoch 191		Train Accuracy: 95.3105 %		Val Accuracy: 73.7531 %
# Epoch 192		Train Accuracy: 95.2266 %		Val Accuracy: 73.6695 %
# Epoch 193		Train Accuracy: 95.2900 %		Val Accuracy: 73.9760 %
# Epoch   194: reducing learning rate of group 0 to 2.3784e-05.
# Epoch 194		Train Accuracy: 95.3022 %		Val Accuracy: 73.8089 %
# Epoch 195		Train Accuracy: 95.3217 %		Val Accuracy: 74.0318 %
# Epoch 196		Train Accuracy: 95.2419 %		Val Accuracy: 73.8089 %
# Epoch 197		Train Accuracy: 95.2774 %		Val Accuracy: 73.7531 %
# Epoch 198		Train Accuracy: 95.3603 %		Val Accuracy: 73.6974 %
# Epoch 199		Train Accuracy: 95.2795 %		Val Accuracy: 74.1432 %
# Epoch   200: reducing learning rate of group 0 to 1.7838e-05.
# Epoch 200		Train Accuracy: 95.3321 %		Val Accuracy: 73.7810 %
# Epoch 201		Train Accuracy: 95.2757 %		Val Accuracy: 73.8924 %
# Epoch 202		Train Accuracy: 95.4206 %		Val Accuracy: 73.6974 %
# Epoch 203		Train Accuracy: 95.2792 %		Val Accuracy: 73.9203 %
# Epoch 204		Train Accuracy: 95.2614 %		Val Accuracy: 73.8646 %
# Epoch 205		Train Accuracy: 95.3231 %		Val Accuracy: 73.8646 %
# Epoch   206: reducing learning rate of group 0 to 1.3379e-05.
# Epoch 206		Train Accuracy: 95.3283 %		Val Accuracy: 73.9482 %
# Epoch 207		Train Accuracy: 95.2611 %		Val Accuracy: 74.0039 %
# Epoch 208		Train Accuracy: 95.2903 %		Val Accuracy: 73.8646 %
# Epoch 209		Train Accuracy: 95.3158 %		Val Accuracy: 73.8089 %
# Epoch 210		Train Accuracy: 95.2437 %		Val Accuracy: 73.5860 %
# Epoch 211		Train Accuracy: 95.3001 %		Val Accuracy: 73.8924 %
# Epoch   212: reducing learning rate of group 0 to 1.0034e-05.
# Epoch 212		Train Accuracy: 95.2753 %		Val Accuracy: 73.6695 %
# Epoch 213		Train Accuracy: 95.3485 %		Val Accuracy: 73.8924 %
# Epoch 214		Train Accuracy: 95.3576 %		Val Accuracy: 73.7253 %
# Epoch 215		Train Accuracy: 95.2388 %		Val Accuracy: 73.9203 %
# Epoch 216		Train Accuracy: 95.3043 %		Val Accuracy: 73.8646 %
# Epoch 217		Train Accuracy: 95.3910 %		Val Accuracy: 73.8924 %
# Epoch   218: reducing learning rate of group 0 to 7.5254e-06.
# Epoch 218		Train Accuracy: 95.2597 %		Val Accuracy: 73.8367 %
# Epoch 219		Train Accuracy: 95.2384 %		Val Accuracy: 73.7253 %
# Epoch 220		Train Accuracy: 95.3736 %		Val Accuracy: 73.8646 %
# Epoch 221		Train Accuracy: 95.2691 %		Val Accuracy: 73.9203 %
# Epoch 222		Train Accuracy: 95.3537 %		Val Accuracy: 73.7531 %
# Epoch 223		Train Accuracy: 95.2715 %		Val Accuracy: 73.8089 %
# Epoch   224: reducing learning rate of group 0 to 5.6441e-06.
# Epoch 224		Train Accuracy: 95.4098 %		Val Accuracy: 73.6974 %
# Epoch 225		Train Accuracy: 95.2816 %		Val Accuracy: 73.8646 %
# Epoch 226		Train Accuracy: 95.3210 %		Val Accuracy: 73.7253 %
# Epoch 227		Train Accuracy: 95.3516 %		Val Accuracy: 74.0318 %
# Epoch 228		Train Accuracy: 95.2384 %		Val Accuracy: 73.9482 %
# Epoch 229		Train Accuracy: 95.3088 %		Val Accuracy: 73.8646 %
# Epoch   230: reducing learning rate of group 0 to 4.2331e-06.
# Epoch 230		Train Accuracy: 95.3677 %		Val Accuracy: 73.7253 %
# Epoch 231		Train Accuracy: 95.4028 %		Val Accuracy: 73.8367 %
# Epoch 232		Train Accuracy: 95.2938 %		Val Accuracy: 73.6695 %
# Epoch 233		Train Accuracy: 95.3276 %		Val Accuracy: 73.7531 %
# Epoch 234		Train Accuracy: 95.2962 %		Val Accuracy: 73.9760 %
# Epoch 235		Train Accuracy: 95.3168 %		Val Accuracy: 73.8089 %
# Epoch   236: reducing learning rate of group 0 to 3.1748e-06.
# Epoch 236		Train Accuracy: 95.2726 %		Val Accuracy: 74.0039 %
# Epoch 237		Train Accuracy: 95.2297 %		Val Accuracy: 73.9203 %
# Epoch 238		Train Accuracy: 95.1994 %		Val Accuracy: 73.7810 %
# Epoch 239		Train Accuracy: 95.3266 %		Val Accuracy: 73.7531 %
# Epoch 240		Train Accuracy: 95.2349 %		Val Accuracy: 73.6417 %
# Epoch 241		Train Accuracy: 95.4384 %		Val Accuracy: 73.7810 %
# Epoch   242: reducing learning rate of group 0 to 2.3811e-06.
# Epoch 242		Train Accuracy: 95.3325 %		Val Accuracy: 73.8089 %
# Epoch 243		Train Accuracy: 95.2865 %		Val Accuracy: 73.8646 %
# Epoch 244		Train Accuracy: 95.3596 %		Val Accuracy: 73.7253 %
# Epoch 245		Train Accuracy: 95.2287 %		Val Accuracy: 73.8089 %
# Epoch 246		Train Accuracy: 95.3408 %		Val Accuracy: 73.8924 %
# Epoch 247		Train Accuracy: 95.3043 %		Val Accuracy: 73.8646 %
# Epoch   248: reducing learning rate of group 0 to 1.7858e-06.
# Epoch 248		Train Accuracy: 95.3245 %		Val Accuracy: 73.8924 %
# Epoch 249		Train Accuracy: 95.2736 %		Val Accuracy: 73.6974 %
# Epoch 250		Train Accuracy: 95.3631 %		Val Accuracy: 73.7531 %
# Epoch 251		Train Accuracy: 95.3213 %		Val Accuracy: 73.8646 %
# Epoch 252		Train Accuracy: 95.4213 %		Val Accuracy: 73.6417 %
# Epoch 253		Train Accuracy: 95.2774 %		Val Accuracy: 73.7531 %
# Epoch   254: reducing learning rate of group 0 to 1.3394e-06.
# Epoch 254		Train Accuracy: 95.3579 %		Val Accuracy: 73.9203 %
# Epoch 255		Train Accuracy: 95.2663 %		Val Accuracy: 73.8924 %
# Epoch 256		Train Accuracy: 95.3158 %		Val Accuracy: 74.0318 %
# Epoch 257		Train Accuracy: 95.2865 %		Val Accuracy: 73.7810 %
# Epoch 258		Train Accuracy: 95.2837 %		Val Accuracy: 73.7531 %
# Epoch 259		Train Accuracy: 95.3290 %		Val Accuracy: 73.9203 %
# Epoch   260: reducing learning rate of group 0 to 1.0045e-06.
# Epoch 260		Train Accuracy: 95.3025 %		Val Accuracy: 73.8646 %
# Epoch 261		Train Accuracy: 95.3311 %		Val Accuracy: 73.8924 %
# Epoch 262		Train Accuracy: 95.3572 %		Val Accuracy: 73.9482 %
# Epoch 263		Train Accuracy: 95.3652 %		Val Accuracy: 73.6695 %
# Epoch 264		Train Accuracy: 95.3137 %		Val Accuracy: 73.7531 %
# Epoch 265		Train Accuracy: 95.2189 %		Val Accuracy: 73.7253 %
# Epoch   266: reducing learning rate of group 0 to 7.5339e-07.
# Epoch 266		Train Accuracy: 95.3635 %		Val Accuracy: 73.9203 %
# Epoch 267		Train Accuracy: 95.3126 %		Val Accuracy: 73.7531 %
# Epoch 268		Train Accuracy: 95.3036 %		Val Accuracy: 73.8646 %
# Epoch 269		Train Accuracy: 95.3945 %		Val Accuracy: 73.8089 %
# Epoch 270		Train Accuracy: 95.3576 %		Val Accuracy: 73.9203 %
# Epoch 271		Train Accuracy: 95.3579 %		Val Accuracy: 73.6695 %
# Epoch   272: reducing learning rate of group 0 to 5.6504e-07.
# Epoch 272		Train Accuracy: 95.3750 %		Val Accuracy: 73.9203 %
# Epoch 273		Train Accuracy: 95.4227 %		Val Accuracy: 73.7810 %
# Epoch 274		Train Accuracy: 95.3175 %		Val Accuracy: 73.6695 %
# Epoch 275		Train Accuracy: 95.3252 %		Val Accuracy: 73.6417 %
# Epoch 276		Train Accuracy: 95.2997 %		Val Accuracy: 73.9203 %
# Epoch 277		Train Accuracy: 95.3328 %		Val Accuracy: 73.8924 %
# Epoch   278: reducing learning rate of group 0 to 4.2378e-07.
# Epoch 278		Train Accuracy: 95.3990 %		Val Accuracy: 73.7531 %
# Epoch 279		Train Accuracy: 95.2924 %		Val Accuracy: 73.9760 %
# Epoch 280		Train Accuracy: 95.3520 %		Val Accuracy: 73.6695 %
# Epoch 281		Train Accuracy: 95.3635 %		Val Accuracy: 73.6974 %
# Epoch 282		Train Accuracy: 95.3422 %		Val Accuracy: 73.7253 %
# Epoch 283		Train Accuracy: 95.3182 %		Val Accuracy: 73.7531 %
# Epoch   284: reducing learning rate of group 0 to 3.1784e-07.
# Epoch 284		Train Accuracy: 95.2914 %		Val Accuracy: 73.8924 %
# Epoch 285		Train Accuracy: 95.3043 %		Val Accuracy: 73.8089 %
# Epoch 286		Train Accuracy: 95.2736 %		Val Accuracy: 73.7531 %
# Epoch 287		Train Accuracy: 95.3798 %		Val Accuracy: 73.8089 %
# Epoch 288		Train Accuracy: 95.2990 %		Val Accuracy: 73.7531 %
# Epoch 289		Train Accuracy: 95.3203 %		Val Accuracy: 73.8089 %
# Epoch   290: reducing learning rate of group 0 to 2.3838e-07.
# Epoch 290		Train Accuracy: 95.4011 %		Val Accuracy: 73.7810 %
# Epoch 291		Train Accuracy: 95.3548 %		Val Accuracy: 73.9203 %
# Epoch 292		Train Accuracy: 95.2478 %		Val Accuracy: 74.0039 %
# Epoch 293		Train Accuracy: 95.3906 %		Val Accuracy: 73.6695 %
# Epoch 294		Train Accuracy: 95.3502 %		Val Accuracy: 73.7810 %
# Epoch 295		Train Accuracy: 95.3572 %		Val Accuracy: 73.9203 %
# Epoch   296: reducing learning rate of group 0 to 1.7878e-07.
# Epoch 296		Train Accuracy: 95.3478 %		Val Accuracy: 73.8367 %
# Epoch 297		Train Accuracy: 95.3137 %		Val Accuracy: 73.8646 %
# Epoch 298		Train Accuracy: 95.2844 %		Val Accuracy: 73.7810 %
# Epoch 299		Train Accuracy: 95.3583 %		Val Accuracy: 73.9760 %
# Epoch 300		Train Accuracy: 95.3610 %		Val Accuracy: 73.7531 %
# Test Accuracy: 72.1092 %		Test Loss: 0.029073

# %%
def setup_network(hps):
    #net = nets[hps['network']]()
    net = EfficientNet()

    # Prepare logger
    logger = Logger()
    if hps['restore_epoch']:
        restore(net, logger, hps)

    return logger, net
hps = {
    'network': 'efn',  # which network do you want to train
    'name': 'myefn',  # whatever you want to name your run
    'n_epochs': 300,
    'model_save_dir': None,  # where will checkpoints be stored (path created automatically using hps[name])
    'restore_epoch': None,  # continue training from a specific saved point
    'start_epoch': 0,
    'lr': 0.01,  # starting learning rate
    'save_freq': 20,  # how often to create checkpoints
    'drop': 0.1,
    'bs': 64,
}
hps['model_save_dir'] = os.path.join(os.getcwd(), 'efncheckpoints', hps['name'])
if not os.path.exists(hps['model_save_dir']):
    os.makedirs(hps['model_save_dir'])
logger, efn = setup_network(hps)
efn
# Out:
# EfficientNet(
#   (model): EfficientNet(
#     (conv_stem): Conv2dSame(3, 40, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): SiLU(inplace=True)
#     (blocks): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (bn1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pw): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn2): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): Identity()
#         )
#         (1): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pw): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn2): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(144, 144, kernel_size=(3, 3), stride=(2, 2), groups=144, bias=False)
#           (bn2): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(192, 192, kernel_size=(5, 5), stride=(2, 2), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#           (bn2): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#           (bn2): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288, bias=False)
#           (bn2): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (bn2): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (bn2): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (bn2): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (bn2): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (bn2): BatchNorm2d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(136, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#           (bn2): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(136, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#           (bn2): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(136, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#           (bn2): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(136, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#           (bn2): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(136, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(816, 816, kernel_size=(5, 5), stride=(2, 2), groups=816, bias=False)
#           (bn2): BatchNorm2d(816, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(232, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1392, bias=False)
#           (bn2): BatchNorm2d(1392, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#           (bn2): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (conv_head): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (act2): SiLU(inplace=True)
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=True)
#     (classifier): Linear(in_features=1536, out_features=7, bias=True)
#   )
# )

# %%
run(efn, logger, hps)
# Out:
# Training myefn on cuda:0
# Epoch  1		Train Accuracy: 33.3728 %		Val Accuracy: 49.0109 %
# Epoch  2		Train Accuracy: 43.4383 %		Val Accuracy: 55.8373 %
# Epoch  3		Train Accuracy: 48.3235 %		Val Accuracy: 59.0694 %
# Epoch  4		Train Accuracy: 50.8001 %		Val Accuracy: 59.9331 %
# Epoch  5		Train Accuracy: 53.0088 %		Val Accuracy: 61.2427 %
# Epoch  6		Train Accuracy: 54.4777 %		Val Accuracy: 62.4408 %
# Epoch  7		Train Accuracy: 55.9107 %		Val Accuracy: 63.4717 %
# Epoch  8		Train Accuracy: 56.8947 %		Val Accuracy: 64.4748 %
# Epoch  9		Train Accuracy: 57.7418 %		Val Accuracy: 64.8649 %
# Epoch 10		Train Accuracy: 58.9582 %		Val Accuracy: 65.6729 %
# Epoch 11		Train Accuracy: 59.7112 %		Val Accuracy: 65.4778 %
# Epoch 12		Train Accuracy: 60.4786 %		Val Accuracy: 67.0660 %
# Epoch 13		Train Accuracy: 61.3149 %		Val Accuracy: 65.8679 %
# Epoch 14		Train Accuracy: 61.8245 %		Val Accuracy: 67.2889 %
# Epoch 15		Train Accuracy: 62.8319 %		Val Accuracy: 67.4840 %
# Epoch 16		Train Accuracy: 63.5174 %		Val Accuracy: 68.2920 %
# Epoch 17		Train Accuracy: 64.2889 %		Val Accuracy: 67.3447 %
# Epoch 18		Train Accuracy: 64.9511 %		Val Accuracy: 68.6542 %
# Epoch 19		Train Accuracy: 65.5066 %		Val Accuracy: 68.3756 %
# Epoch 20		Train Accuracy: 66.4537 %		Val Accuracy: 67.8183 %
# Epoch 21		Train Accuracy: 67.2246 %		Val Accuracy: 67.8741 %
# Epoch 22		Train Accuracy: 67.8885 %		Val Accuracy: 68.6542 %
# Epoch 23		Train Accuracy: 68.6879 %		Val Accuracy: 69.1836 %
# Epoch 24		Train Accuracy: 69.2417 %		Val Accuracy: 68.7935 %
# Epoch 25		Train Accuracy: 69.7203 %		Val Accuracy: 69.0164 %
# Epoch 26		Train Accuracy: 70.9272 %		Val Accuracy: 69.6851 %
# Epoch 27		Train Accuracy: 71.7291 %		Val Accuracy: 69.0443 %
# Epoch 28		Train Accuracy: 72.3338 %		Val Accuracy: 70.0752 %
# Epoch 29		Train Accuracy: 73.0287 %		Val Accuracy: 68.7099 %
# Epoch 30		Train Accuracy: 73.7173 %		Val Accuracy: 69.2115 %
# Epoch 31		Train Accuracy: 74.4679 %		Val Accuracy: 68.8214 %
# Epoch 32		Train Accuracy: 75.2189 %		Val Accuracy: 69.6851 %
# Epoch 33		Train Accuracy: 75.8811 %		Val Accuracy: 68.7657 %
# Epoch    34: reducing learning rate of group 0 to 7.5000e-03.
# Epoch 34		Train Accuracy: 76.5283 %		Val Accuracy: 69.7966 %
# Epoch 35		Train Accuracy: 78.1929 %		Val Accuracy: 69.2672 %
# Epoch 36		Train Accuracy: 79.1173 %		Val Accuracy: 69.3229 %
# Epoch 37		Train Accuracy: 79.5907 %		Val Accuracy: 69.0722 %
# Epoch 38		Train Accuracy: 79.8885 %		Val Accuracy: 68.9050 %
# Epoch 39		Train Accuracy: 80.5378 %		Val Accuracy: 69.5458 %
# Epoch    40: reducing learning rate of group 0 to 5.6250e-03.
# Epoch 40		Train Accuracy: 80.9154 %		Val Accuracy: 69.9359 %
# Epoch 41		Train Accuracy: 82.3163 %		Val Accuracy: 69.7130 %
# Epoch 42		Train Accuracy: 82.7695 %		Val Accuracy: 69.9359 %
# Epoch 43		Train Accuracy: 83.1899 %		Val Accuracy: 69.4622 %
# Epoch 44		Train Accuracy: 83.5689 %		Val Accuracy: 70.1310 %
# Epoch 45		Train Accuracy: 84.0796 %		Val Accuracy: 69.6016 %
# Epoch 46		Train Accuracy: 84.2757 %		Val Accuracy: 70.1310 %
# Epoch 47		Train Accuracy: 84.4592 %		Val Accuracy: 69.5458 %
# Epoch 48		Train Accuracy: 84.8096 %		Val Accuracy: 69.9081 %
# Epoch 49		Train Accuracy: 85.1750 %		Val Accuracy: 69.6573 %
# Epoch    50: reducing learning rate of group 0 to 4.2188e-03.
# Epoch 50		Train Accuracy: 85.3872 %		Val Accuracy: 69.9359 %
# Epoch 51		Train Accuracy: 86.2371 %		Val Accuracy: 70.1310 %
# Epoch 52		Train Accuracy: 86.6282 %		Val Accuracy: 70.7161 %
# Epoch 53		Train Accuracy: 86.7979 %		Val Accuracy: 69.8245 %
# Epoch 54		Train Accuracy: 87.0427 %		Val Accuracy: 70.1310 %
# Epoch 55		Train Accuracy: 87.1009 %		Val Accuracy: 70.2145 %
# Epoch 56		Train Accuracy: 87.3465 %		Val Accuracy: 70.6604 %
# Epoch 57		Train Accuracy: 87.4963 %		Val Accuracy: 70.3260 %
# Epoch    58: reducing learning rate of group 0 to 3.1641e-03.
# Epoch 58		Train Accuracy: 87.7390 %		Val Accuracy: 70.0474 %
# Epoch 59		Train Accuracy: 88.2486 %		Val Accuracy: 70.1310 %
# Epoch 60		Train Accuracy: 88.3758 %		Val Accuracy: 70.5489 %
# Epoch 61		Train Accuracy: 88.8666 %		Val Accuracy: 70.0195 %
# Epoch 62		Train Accuracy: 88.8481 %		Val Accuracy: 70.0752 %
# Epoch 63		Train Accuracy: 89.0526 %		Val Accuracy: 70.1310 %
# Epoch    64: reducing learning rate of group 0 to 2.3730e-03.
# Epoch 64		Train Accuracy: 88.8958 %		Val Accuracy: 69.8245 %
# Epoch 65		Train Accuracy: 89.5224 %		Val Accuracy: 70.4374 %
# Epoch 66		Train Accuracy: 89.6646 %		Val Accuracy: 70.6882 %
# Epoch 67		Train Accuracy: 89.7227 %		Val Accuracy: 70.3817 %
# Epoch 68		Train Accuracy: 89.9289 %		Val Accuracy: 70.0752 %
# Epoch 69		Train Accuracy: 89.8878 %		Val Accuracy: 69.9081 %
# Epoch    70: reducing learning rate of group 0 to 1.7798e-03.
# Epoch 70		Train Accuracy: 90.0467 %		Val Accuracy: 70.4096 %
# Epoch 71		Train Accuracy: 90.3271 %		Val Accuracy: 70.3817 %
# Epoch 72		Train Accuracy: 90.4100 %		Val Accuracy: 70.2703 %
# Epoch 73		Train Accuracy: 90.4340 %		Val Accuracy: 70.5210 %
# Epoch 74		Train Accuracy: 90.4368 %		Val Accuracy: 70.5210 %
# Epoch 75		Train Accuracy: 90.5901 %		Val Accuracy: 70.2145 %
# Epoch    76: reducing learning rate of group 0 to 1.3348e-03.
# Epoch 76		Train Accuracy: 90.6409 %		Val Accuracy: 70.4096 %
# Epoch 77		Train Accuracy: 91.0014 %		Val Accuracy: 70.6604 %
# Epoch 78		Train Accuracy: 90.9077 %		Val Accuracy: 70.6882 %
# Epoch 79		Train Accuracy: 90.9460 %		Val Accuracy: 70.5210 %
# Epoch 80		Train Accuracy: 91.0746 %		Val Accuracy: 70.3260 %
# Epoch 81		Train Accuracy: 91.1700 %		Val Accuracy: 70.8554 %
# Epoch 82		Train Accuracy: 91.1247 %		Val Accuracy: 70.6046 %
# Epoch 83		Train Accuracy: 91.0572 %		Val Accuracy: 70.1588 %
# Epoch 84		Train Accuracy: 91.2665 %		Val Accuracy: 70.4096 %
# Epoch 85		Train Accuracy: 91.2404 %		Val Accuracy: 70.3817 %
# Epoch 86		Train Accuracy: 91.3940 %		Val Accuracy: 70.3817 %
# Epoch    87: reducing learning rate of group 0 to 1.0011e-03.
# Epoch 87		Train Accuracy: 91.3734 %		Val Accuracy: 70.6046 %
# Epoch 88		Train Accuracy: 91.6740 %		Val Accuracy: 70.6604 %
# Epoch 89		Train Accuracy: 91.7033 %		Val Accuracy: 70.1310 %
# Epoch 90		Train Accuracy: 91.7113 %		Val Accuracy: 70.2145 %
# Epoch 91		Train Accuracy: 91.6678 %		Val Accuracy: 70.4932 %
# Epoch 92		Train Accuracy: 91.8273 %		Val Accuracy: 69.9916 %
# Epoch    93: reducing learning rate of group 0 to 7.5085e-04.
# Epoch 93		Train Accuracy: 91.8061 %		Val Accuracy: 70.5210 %
# Epoch 94		Train Accuracy: 91.7998 %		Val Accuracy: 70.7439 %
# Epoch 95		Train Accuracy: 91.8681 %		Val Accuracy: 70.3539 %
# Epoch 96		Train Accuracy: 91.9645 %		Val Accuracy: 70.4932 %
# Epoch 97		Train Accuracy: 91.8886 %		Val Accuracy: 70.6604 %
# Epoch 98		Train Accuracy: 91.9213 %		Val Accuracy: 70.5489 %
# Epoch    99: reducing learning rate of group 0 to 5.6314e-04.
# Epoch 99		Train Accuracy: 92.0283 %		Val Accuracy: 70.7161 %
# Epoch 100		Train Accuracy: 92.0074 %		Val Accuracy: 69.9359 %
# Epoch 101		Train Accuracy: 92.1450 %		Val Accuracy: 70.8833 %
# Epoch 102		Train Accuracy: 91.9917 %		Val Accuracy: 70.4096 %
# Epoch 103		Train Accuracy: 92.2763 %		Val Accuracy: 70.4653 %
# Epoch 104		Train Accuracy: 92.2220 %		Val Accuracy: 70.5768 %
# Epoch 105		Train Accuracy: 92.2324 %		Val Accuracy: 70.1867 %
# Epoch 106		Train Accuracy: 92.2118 %		Val Accuracy: 70.3539 %
# Epoch   107: reducing learning rate of group 0 to 4.2235e-04.
# Epoch 107		Train Accuracy: 92.1892 %		Val Accuracy: 70.2703 %
# Epoch 108		Train Accuracy: 92.2707 %		Val Accuracy: 70.1867 %
# Epoch 109		Train Accuracy: 92.2850 %		Val Accuracy: 70.1867 %
# Epoch 110		Train Accuracy: 92.3254 %		Val Accuracy: 70.2424 %
# Epoch 111		Train Accuracy: 92.3550 %		Val Accuracy: 70.2145 %
# Epoch 112		Train Accuracy: 92.2857 %		Val Accuracy: 70.1310 %
# Epoch   113: reducing learning rate of group 0 to 3.1676e-04.
# Epoch 113		Train Accuracy: 92.3066 %		Val Accuracy: 70.4096 %
# Epoch 114		Train Accuracy: 92.4703 %		Val Accuracy: 70.5489 %
# Epoch 115		Train Accuracy: 92.4351 %		Val Accuracy: 70.7161 %
# Epoch 116		Train Accuracy: 92.4780 %		Val Accuracy: 70.4096 %
# Epoch 117		Train Accuracy: 92.4118 %		Val Accuracy: 70.0752 %
# Epoch 118		Train Accuracy: 92.4787 %		Val Accuracy: 70.5210 %
# Epoch 119		Train Accuracy: 92.4240 %		Val Accuracy: 71.0226 %
# Epoch 120		Train Accuracy: 92.4922 %		Val Accuracy: 70.5489 %
# Epoch 121		Train Accuracy: 92.4609 %		Val Accuracy: 70.6046 %
# Epoch 122		Train Accuracy: 92.5271 %		Val Accuracy: 70.4932 %
# Epoch 123		Train Accuracy: 92.5292 %		Val Accuracy: 70.5210 %
# Epoch 124		Train Accuracy: 92.4205 %		Val Accuracy: 70.4374 %
# Epoch   125: reducing learning rate of group 0 to 2.3757e-04.
# Epoch 125		Train Accuracy: 92.4947 %		Val Accuracy: 70.4653 %
# Epoch 126		Train Accuracy: 92.5093 %		Val Accuracy: 70.4374 %
# Epoch 127		Train Accuracy: 92.6253 %		Val Accuracy: 70.5489 %
# Epoch 128		Train Accuracy: 92.5633 %		Val Accuracy: 70.4932 %
# Epoch 129		Train Accuracy: 92.5933 %		Val Accuracy: 70.6882 %
# Epoch 130		Train Accuracy: 92.6163 %		Val Accuracy: 70.3539 %
# Epoch   131: reducing learning rate of group 0 to 1.7818e-04.
# Epoch 131		Train Accuracy: 92.6055 %		Val Accuracy: 70.4374 %
# Epoch 132		Train Accuracy: 92.7235 %		Val Accuracy: 70.2703 %
# Epoch 133		Train Accuracy: 92.4926 %		Val Accuracy: 70.4096 %
# Epoch 134		Train Accuracy: 92.6814 %		Val Accuracy: 70.1867 %
# Epoch 135		Train Accuracy: 92.7284 %		Val Accuracy: 70.2145 %
# Epoch 136		Train Accuracy: 92.6295 %		Val Accuracy: 70.4374 %
# Epoch   137: reducing learning rate of group 0 to 1.3363e-04.
# Epoch 137		Train Accuracy: 92.6553 %		Val Accuracy: 70.6046 %
# Epoch 138		Train Accuracy: 92.6521 %		Val Accuracy: 70.1031 %
# Epoch 139		Train Accuracy: 92.6925 %		Val Accuracy: 70.3539 %
# Epoch 140		Train Accuracy: 92.6486 %		Val Accuracy: 70.2703 %
# Epoch 141		Train Accuracy: 92.7458 %		Val Accuracy: 70.3817 %
# Epoch 142		Train Accuracy: 92.7430 %		Val Accuracy: 70.4653 %
# Epoch   143: reducing learning rate of group 0 to 1.0023e-04.
# Epoch 143		Train Accuracy: 92.5633 %		Val Accuracy: 70.1310 %
# Epoch 144		Train Accuracy: 92.6250 %		Val Accuracy: 70.2981 %
# Epoch 145		Train Accuracy: 92.7949 %		Val Accuracy: 70.2424 %
# Epoch 146		Train Accuracy: 92.7462 %		Val Accuracy: 70.3260 %
# Epoch 147		Train Accuracy: 92.7629 %		Val Accuracy: 70.2981 %
# Epoch 148		Train Accuracy: 92.7458 %		Val Accuracy: 70.6046 %
# Epoch   149: reducing learning rate of group 0 to 7.5169e-05.
# Epoch 149		Train Accuracy: 92.6810 %		Val Accuracy: 70.2145 %
# Epoch 150		Train Accuracy: 92.8500 %		Val Accuracy: 70.3260 %
# Epoch 151		Train Accuracy: 92.8305 %		Val Accuracy: 70.3260 %
# Epoch 152		Train Accuracy: 92.8266 %		Val Accuracy: 70.3817 %
# Epoch 153		Train Accuracy: 92.6971 %		Val Accuracy: 70.4653 %
# Epoch 154		Train Accuracy: 92.8611 %		Val Accuracy: 70.5768 %
# Epoch   155: reducing learning rate of group 0 to 5.6377e-05.
# Epoch 155		Train Accuracy: 92.7584 %		Val Accuracy: 70.3539 %
# Epoch 156		Train Accuracy: 92.7016 %		Val Accuracy: 70.6046 %
# Epoch 157		Train Accuracy: 92.6448 %		Val Accuracy: 70.4374 %
# Epoch 158		Train Accuracy: 92.7702 %		Val Accuracy: 70.4932 %
# Epoch 159		Train Accuracy: 92.8054 %		Val Accuracy: 70.4653 %
# Epoch 160		Train Accuracy: 92.8016 %		Val Accuracy: 70.1588 %
# Epoch   161: reducing learning rate of group 0 to 4.2283e-05.
# Epoch 161		Train Accuracy: 92.8643 %		Val Accuracy: 70.5210 %
# Epoch 162		Train Accuracy: 92.7194 %		Val Accuracy: 70.5489 %
# Epoch 163		Train Accuracy: 92.8155 %		Val Accuracy: 70.2424 %
# Epoch 164		Train Accuracy: 92.7187 %		Val Accuracy: 70.5210 %
# Epoch 165		Train Accuracy: 92.7497 %		Val Accuracy: 70.6325 %
# Epoch 166		Train Accuracy: 92.8956 %		Val Accuracy: 70.4096 %
# Epoch   167: reducing learning rate of group 0 to 3.1712e-05.
# Epoch 167		Train Accuracy: 92.6999 %		Val Accuracy: 70.1031 %
# Epoch 168		Train Accuracy: 92.7723 %		Val Accuracy: 70.4932 %
# Epoch 169		Train Accuracy: 92.8294 %		Val Accuracy: 70.2703 %
# Epoch 170		Train Accuracy: 92.7681 %		Val Accuracy: 70.7161 %
# Epoch 171		Train Accuracy: 92.9489 %		Val Accuracy: 70.3260 %
# Epoch 172		Train Accuracy: 92.7692 %		Val Accuracy: 70.3260 %
# Epoch   173: reducing learning rate of group 0 to 2.3784e-05.
# Epoch 173		Train Accuracy: 92.8162 %		Val Accuracy: 70.1310 %
# Epoch 174		Train Accuracy: 92.8092 %		Val Accuracy: 70.4374 %
# Epoch 175		Train Accuracy: 92.8573 %		Val Accuracy: 70.0195 %
# Epoch 176		Train Accuracy: 92.6911 %		Val Accuracy: 69.8523 %
# Epoch 177		Train Accuracy: 92.7521 %		Val Accuracy: 70.2981 %
# Epoch 178		Train Accuracy: 92.9252 %		Val Accuracy: 70.2703 %
# Epoch   179: reducing learning rate of group 0 to 1.7838e-05.
# Epoch 179		Train Accuracy: 92.6981 %		Val Accuracy: 69.9916 %
# Epoch 180		Train Accuracy: 92.8695 %		Val Accuracy: 70.6046 %
# Epoch 181		Train Accuracy: 92.8099 %		Val Accuracy: 70.4932 %
# Epoch 182		Train Accuracy: 92.8514 %		Val Accuracy: 70.0195 %
# Epoch 183		Train Accuracy: 93.0367 %		Val Accuracy: 70.5768 %
# Epoch 184		Train Accuracy: 92.7601 %		Val Accuracy: 70.3539 %
# Epoch   185: reducing learning rate of group 0 to 1.3379e-05.
# Epoch 185		Train Accuracy: 92.7657 %		Val Accuracy: 70.3539 %
# Epoch 186		Train Accuracy: 92.7932 %		Val Accuracy: 70.0752 %
# Epoch 187		Train Accuracy: 92.8322 %		Val Accuracy: 70.4096 %
# Epoch 188		Train Accuracy: 92.8353 %		Val Accuracy: 70.5210 %
# Epoch 189		Train Accuracy: 92.7584 %		Val Accuracy: 70.2703 %
# Epoch 190		Train Accuracy: 92.8646 %		Val Accuracy: 70.5210 %
# Epoch   191: reducing learning rate of group 0 to 1.0034e-05.
# Epoch 191		Train Accuracy: 92.8221 %		Val Accuracy: 70.3539 %
# Epoch 192		Train Accuracy: 93.0262 %		Val Accuracy: 70.4932 %
# Epoch 193		Train Accuracy: 92.8789 %		Val Accuracy: 70.6604 %
# Epoch 194		Train Accuracy: 92.9332 %		Val Accuracy: 70.6046 %
# Epoch 195		Train Accuracy: 92.8430 %		Val Accuracy: 70.4653 %
# Epoch 196		Train Accuracy: 92.8378 %		Val Accuracy: 70.3817 %
# Epoch   197: reducing learning rate of group 0 to 7.5254e-06.
# Epoch 197		Train Accuracy: 92.6971 %		Val Accuracy: 70.3260 %
# Epoch 198		Train Accuracy: 92.8430 %		Val Accuracy: 70.6046 %
# Epoch 199		Train Accuracy: 92.9496 %		Val Accuracy: 70.1867 %
# Epoch 200		Train Accuracy: 92.8371 %		Val Accuracy: 70.4932 %
# Epoch 201		Train Accuracy: 92.7326 %		Val Accuracy: 70.2981 %
# Epoch 202		Train Accuracy: 92.9301 %		Val Accuracy: 70.5489 %
# Epoch   203: reducing learning rate of group 0 to 5.6441e-06.
# Epoch 203		Train Accuracy: 92.8009 %		Val Accuracy: 70.3817 %
# Epoch 204		Train Accuracy: 92.9914 %		Val Accuracy: 70.2703 %
# Epoch 205		Train Accuracy: 92.8458 %		Val Accuracy: 70.3817 %
# Epoch 206		Train Accuracy: 92.8468 %		Val Accuracy: 70.1031 %
# Epoch 207		Train Accuracy: 92.8054 %		Val Accuracy: 70.4096 %
# Epoch 208		Train Accuracy: 92.7737 %		Val Accuracy: 70.3817 %
# Epoch   209: reducing learning rate of group 0 to 4.2331e-06.
# Epoch 209		Train Accuracy: 92.9890 %		Val Accuracy: 70.4096 %
# Epoch 210		Train Accuracy: 92.9057 %		Val Accuracy: 70.3817 %
# Epoch 211		Train Accuracy: 92.8771 %		Val Accuracy: 70.4096 %
# Epoch 212		Train Accuracy: 92.8754 %		Val Accuracy: 70.3260 %
# Epoch 213		Train Accuracy: 92.8813 %		Val Accuracy: 70.6325 %
# Epoch 214		Train Accuracy: 92.9646 %		Val Accuracy: 70.1588 %
# Epoch   215: reducing learning rate of group 0 to 3.1748e-06.
# Epoch 215		Train Accuracy: 92.9120 %		Val Accuracy: 70.8275 %
# Epoch 216		Train Accuracy: 92.7629 %		Val Accuracy: 70.6046 %
# Epoch 217		Train Accuracy: 92.8970 %		Val Accuracy: 70.5489 %
# Epoch 218		Train Accuracy: 93.0297 %		Val Accuracy: 70.3539 %
# Epoch 219		Train Accuracy: 92.9409 %		Val Accuracy: 70.3817 %
# Epoch 220		Train Accuracy: 92.9148 %		Val Accuracy: 70.4096 %
# Epoch   221: reducing learning rate of group 0 to 2.3811e-06.
# Epoch 221		Train Accuracy: 92.7974 %		Val Accuracy: 70.3539 %
# Epoch 222		Train Accuracy: 92.9054 %		Val Accuracy: 70.5768 %
# Epoch 223		Train Accuracy: 92.9308 %		Val Accuracy: 70.2981 %
# Epoch 224		Train Accuracy: 92.9423 %		Val Accuracy: 70.3817 %
# Epoch 225		Train Accuracy: 92.9022 %		Val Accuracy: 70.5489 %
# Epoch 226		Train Accuracy: 92.8430 %		Val Accuracy: 70.4932 %
# Epoch   227: reducing learning rate of group 0 to 1.7858e-06.
# Epoch 227		Train Accuracy: 92.9012 %		Val Accuracy: 70.2145 %
# Epoch 228		Train Accuracy: 92.8939 %		Val Accuracy: 70.3260 %
# Epoch 229		Train Accuracy: 92.9036 %		Val Accuracy: 70.2981 %
# Epoch 230		Train Accuracy: 92.8245 %		Val Accuracy: 70.5210 %
# Epoch 231		Train Accuracy: 92.8075 %		Val Accuracy: 70.5489 %
# Epoch 232		Train Accuracy: 92.6427 %		Val Accuracy: 70.2703 %
# Epoch   233: reducing learning rate of group 0 to 1.3394e-06.
# Epoch 233		Train Accuracy: 93.0025 %		Val Accuracy: 70.5768 %
# Epoch 234		Train Accuracy: 92.7528 %		Val Accuracy: 69.9081 %
# Epoch 235		Train Accuracy: 92.8510 %		Val Accuracy: 70.4932 %
# Epoch 236		Train Accuracy: 92.8430 %		Val Accuracy: 70.2424 %
# Epoch 237		Train Accuracy: 92.8489 %		Val Accuracy: 70.3817 %
# Epoch 238		Train Accuracy: 92.9033 %		Val Accuracy: 70.2145 %
# Epoch   239: reducing learning rate of group 0 to 1.0045e-06.
# Epoch 239		Train Accuracy: 92.8594 %		Val Accuracy: 70.3260 %
# Epoch 240		Train Accuracy: 92.8883 %		Val Accuracy: 70.2424 %
# Epoch 241		Train Accuracy: 92.8914 %		Val Accuracy: 70.3817 %
# Epoch 242		Train Accuracy: 92.7664 %		Val Accuracy: 70.4653 %
# Epoch 243		Train Accuracy: 92.7890 %		Val Accuracy: 70.4932 %
# Epoch 244		Train Accuracy: 92.8148 %		Val Accuracy: 70.3260 %
# Epoch   245: reducing learning rate of group 0 to 7.5339e-07.
# Epoch 245		Train Accuracy: 92.8378 %		Val Accuracy: 70.7997 %
# Epoch 246		Train Accuracy: 92.7281 %		Val Accuracy: 70.4096 %
# Epoch 247		Train Accuracy: 92.7862 %		Val Accuracy: 70.2703 %
# Epoch 248		Train Accuracy: 92.8583 %		Val Accuracy: 70.2981 %
# Epoch 249		Train Accuracy: 92.7619 %		Val Accuracy: 70.2981 %
# Epoch 250		Train Accuracy: 92.9614 %		Val Accuracy: 70.1867 %
# Epoch   251: reducing learning rate of group 0 to 5.6504e-07.
# Epoch 251		Train Accuracy: 92.9527 %		Val Accuracy: 70.3817 %
# Epoch 252		Train Accuracy: 92.8489 %		Val Accuracy: 70.7439 %
# Epoch 253		Train Accuracy: 92.8576 %		Val Accuracy: 70.4096 %
# Epoch 254		Train Accuracy: 92.7915 %		Val Accuracy: 70.4096 %
# Epoch 255		Train Accuracy: 92.7925 %		Val Accuracy: 70.3817 %
# Epoch 256		Train Accuracy: 92.8691 %		Val Accuracy: 70.4096 %
# Epoch   257: reducing learning rate of group 0 to 4.2378e-07.
# Epoch 257		Train Accuracy: 92.8879 %		Val Accuracy: 70.2981 %
# Epoch 258		Train Accuracy: 92.9068 %		Val Accuracy: 70.2703 %
# Epoch 259		Train Accuracy: 92.8601 %		Val Accuracy: 70.4374 %
# Epoch 260		Train Accuracy: 92.9182 %		Val Accuracy: 70.3539 %
# Epoch 261		Train Accuracy: 92.8667 %		Val Accuracy: 70.3260 %
# Epoch 262		Train Accuracy: 92.9329 %		Val Accuracy: 70.4932 %
# Epoch   263: reducing learning rate of group 0 to 3.1784e-07.
# Epoch 263		Train Accuracy: 92.9684 %		Val Accuracy: 70.2424 %
# Epoch 264		Train Accuracy: 92.8538 %		Val Accuracy: 69.9916 %
# Epoch 265		Train Accuracy: 92.8723 %		Val Accuracy: 70.4096 %
# Epoch 266		Train Accuracy: 92.8528 %		Val Accuracy: 70.1588 %
# Epoch 267		Train Accuracy: 92.8454 %		Val Accuracy: 70.6046 %
# Epoch 268		Train Accuracy: 92.9465 %		Val Accuracy: 70.2981 %
# Epoch   269: reducing learning rate of group 0 to 2.3838e-07.
# Epoch 269		Train Accuracy: 92.8489 %		Val Accuracy: 70.1867 %
# Epoch 270		Train Accuracy: 92.8437 %		Val Accuracy: 70.2981 %
# Epoch 271		Train Accuracy: 92.9231 %		Val Accuracy: 70.3817 %
# Epoch 272		Train Accuracy: 92.7841 %		Val Accuracy: 70.1867 %
# Epoch 273		Train Accuracy: 92.7960 %		Val Accuracy: 70.4932 %
# Epoch 274		Train Accuracy: 92.9374 %		Val Accuracy: 70.3539 %
# Epoch   275: reducing learning rate of group 0 to 1.7878e-07.
# Epoch 275		Train Accuracy: 92.8559 %		Val Accuracy: 70.4653 %
# Epoch 276		Train Accuracy: 92.7831 %		Val Accuracy: 70.4653 %
# Epoch 277		Train Accuracy: 92.7716 %		Val Accuracy: 70.2981 %
# Epoch 278		Train Accuracy: 92.8465 %		Val Accuracy: 70.3817 %
# Epoch 279		Train Accuracy: 92.8768 %		Val Accuracy: 70.3260 %
# Epoch 280		Train Accuracy: 92.8590 %		Val Accuracy: 70.5768 %
# Epoch   281: reducing learning rate of group 0 to 1.3409e-07.
# Epoch 281		Train Accuracy: 92.9350 %		Val Accuracy: 70.6604 %
# Epoch 282		Train Accuracy: 92.8454 %		Val Accuracy: 70.1867 %
# Epoch 283		Train Accuracy: 92.6821 %		Val Accuracy: 70.5768 %
# Epoch 284		Train Accuracy: 92.7981 %		Val Accuracy: 70.4374 %
# Epoch 285		Train Accuracy: 92.9207 %		Val Accuracy: 70.4096 %
# Epoch 286		Train Accuracy: 92.8831 %		Val Accuracy: 70.0195 %
# Epoch   287: reducing learning rate of group 0 to 1.0057e-07.
# Epoch 287		Train Accuracy: 92.9064 %		Val Accuracy: 70.6046 %
# Epoch 288		Train Accuracy: 92.9130 %		Val Accuracy: 70.4932 %
# Epoch 289		Train Accuracy: 92.9482 %		Val Accuracy: 70.1867 %
# Epoch 290		Train Accuracy: 92.9085 %		Val Accuracy: 70.2703 %
# Epoch 291		Train Accuracy: 92.9346 %		Val Accuracy: 70.3539 %
# Epoch 292		Train Accuracy: 92.8353 %		Val Accuracy: 70.4096 %
# Epoch   293: reducing learning rate of group 0 to 7.5424e-08.
# Epoch 293		Train Accuracy: 92.8190 %		Val Accuracy: 70.4932 %
# Epoch 294		Train Accuracy: 92.8684 %		Val Accuracy: 70.4932 %
# Epoch 295		Train Accuracy: 92.8413 %		Val Accuracy: 70.4096 %
# Epoch 296		Train Accuracy: 92.8904 %		Val Accuracy: 70.1031 %
# Epoch 297		Train Accuracy: 92.9656 %		Val Accuracy: 70.3260 %
# Epoch 298		Train Accuracy: 92.8468 %		Val Accuracy: 70.5489 %
# Epoch   299: reducing learning rate of group 0 to 5.6568e-08.
# Epoch 299		Train Accuracy: 92.8193 %		Val Accuracy: 70.3817 %
# Epoch 300		Train Accuracy: 92.7977 %		Val Accuracy: 70.1867 %
# Test Accuracy: 69.1836 %		Test Loss: 0.026019
